# %% [markdown]
# Phương pháp chọn điểm lấy dữ liệu trên Việt Nam sẽ là chia Việt Nam thành các ô lưới 40k (được tạo ra từ lưới 10k), lọc và giữ lại các ô chứa vị trí
# lấy dữ liệu xác định trong file csv/sample.csv.
#
#
# Chương trình sau đây sẽ:
# - Ghép tạo lưới 40k từ lưới 10k,
# - Lọc và chỉ giữ lại các ô có chứa các điểm trong csv/sample.csv
# - Lưu kết quả vào file grid_40km_with_points_1.gpkg
# - Từ các ô lưới 40k, sẽ xác định các ngày có dữ liệu Sentinel-1 của từng ô. Như vậy để sau này khi xử lý giá trị sm 1km NSIDC của các điểm
#   thuộc các ô lưới 40k, ta sẽ chỉ giữ lại các giá trị sm có ngày có dữ liệu Sentinel-1.
#
#   Đầu ra sẽ là các file csv chứa ngày có dữ liệu Sentinel-1 của từng ô trong thư mục: s1_dates_per_grid

# %% [markdown]
# ### Merge 10k grid into 40k grid, then filter 40k grid cells and retain grid cells containing points in csv/sample.csv

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# Load 10k grid
grid = gpd.read_file("grid/Grid_10K/grid_10km.gpkg").to_crs("EPSG:4326")

# Create 'row' and 'col' if not available in the grid
if 'row' not in grid.columns or 'col' not in grid.columns:
    grid['centroid_x'] = grid.centroid.x.round(4)
    grid['centroid_y'] = grid.centroid.y.round(4)
    grid['row'] = grid['centroid_y'].rank(method='dense').astype(int)
    grid['col'] = grid['centroid_x'].rank(method='dense').astype(int)

# Merge 10k grid into 40k grid by grouping into 2x2 blocks
# Assign group id for each 2x2 block (4 cells)
grid['group_id'] = ((grid['row'] // 3).astype(int)).astype(str) + '_' + ((grid['col'] // 3).astype(int)).astype(str)

# Dissolve by group_id
merged_grid = grid.dissolve(by='group_id', as_index=False)

# Keep only geometry and group_id properties
merged_grid = merged_grid[['group_id', 'geometry']]

# Assign new sequential IDs starting from 1 for simplicity 
merged_grid = merged_grid.reset_index(drop=True)
merged_grid['id'] = range(1, len(merged_grid) + 1)

""" Now filtered 40k grids, keep only those containing points from csv/sample.csv """
# Load points from CSV and create GeoDataFrame
points_df = pd.read_csv("csv/sample.csv")
geometry = [Point(xy) for xy in zip(points_df['lon'], points_df['lat'])]
points_gdf = gpd.GeoDataFrame(points_df, geometry=geometry, crs="EPSG:4326")

# Filter merged grid to keep only those containing points
joined = gpd.sjoin(merged_grid, points_gdf, how="inner", predicate="contains")
selected_grid = merged_grid[merged_grid['group_id'].isin(joined['group_id'])]
# Copy 'id' column with name 'grid_id'
selected_grid['grid_id'] = selected_grid['id']

# Save the selected grid to a new GeoPackage file
selected_grid.to_file("grid/grid_40km_with_points_1.gpkg", driver="GPKG")

# %% [markdown]
# ### Get Sentinel-1 dates on each filtered 40k grid cell

# %%
import ee
import geopandas as gpd
import json
import os
import time

# Authenticate and initialize Earth Engine
ee.Initialize()

# Get Sentinel-1 dates for each grid cell from 2021 to 2022
start_date = "2021-01-01"
end_date = "2022-12-31"

# INPUT : filtered 40k grid file 
grid_file = "grid/grid_40km_with_points_1.gpkg"  # Must contain a 'grid_id' column
output_dir = "s1_dates_per_grid"
os.makedirs(output_dir, exist_ok=True)

# === Load grid geometries ===
grid_gdf = gpd.read_file(grid_file).to_crs("EPSG:4326")

# Function to get Sentinel-1 dates for a given geometry and date range
def get_s1_dates(geom, start_date, end_date, orbit_pass):
    ee_geom = ee.Geometry(geom.__geo_interface__)
    s1 = ee.ImageCollection("COPERNICUS/S1_GRD") \
        .filterDate(start_date, end_date) \
        .filterBounds(ee_geom) \
        .filter(ee.Filter.eq("instrumentMode", "IW")) \
        .filter(ee.Filter.eq("orbitProperties_pass", orbit_pass)) \
        .select(["VV", "VH"])
    
    dates = s1.aggregate_array("system:time_start").getInfo()
    unique_dates = sorted(set([
        ee.Date(d).format("YYYY-MM-dd").getInfo() for d in dates
    ]))
    # Return Sentinel-1 dates as a list of unique date strings
    return unique_dates

# Loop through each grid cell and retrieve Sentinel-1 dates
for _, row in grid_gdf.iterrows():
    grid_id = row["id"]
    geom = row["geometry"]
    # Check if dates already exist for this grid_id
    if os.path.exists(os.path.join(output_dir, f"s1_dates_{grid_id}.json")):
        print(f"Already retrieved {grid_id} data")
        continue
    try:
        ascending_dates = get_s1_dates(geom, start_date, end_date, "ASCENDING")
        descending_dates = get_s1_dates(geom, start_date, end_date, "DESCENDING")

        if not ascending_dates and not descending_dates:
            print(f"No Sentinel-1 data for {grid_id}")
            continue
        
        # Save the dates to a JSON file
        out_data = {
            "grid_id": grid_id,
            "ascending": ascending_dates,
            "descending": descending_dates
        }

        out_path = os.path.join(output_dir, f"s1_dates_{grid_id}.json")
        with open(out_path, "w") as f:
            json.dump(out_data, f)

        print(f"Saved dates for {grid_id}: {len(ascending_dates)} ASC, {len(descending_dates)} DESC")

        time.sleep(5)

    except Exception as e:
        print(f"Failed for {grid_id}: {e}")
# Out:
# Already retrieved 12 data
# Already retrieved 13 data
# Already retrieved 14 data
# Already retrieved 15 data
# Already retrieved 16 data
# Already retrieved 17 data
# Already retrieved 18 data
# Already retrieved 19 data
# Already retrieved 24 data
# Already retrieved 25 data
# Already retrieved 26 data
# Already retrieved 27 data
# Already retrieved 28 data
# Already retrieved 29 data
# Already retrieved 30 data
# Already retrieved 31 data
# Already retrieved 32 data
# Already retrieved 33 data
# Already retrieved 42 data
# Already retrieved 43 data
# Already retrieved 44 data
# Already retrieved 45 data
# Already retrieved 46 data
# Already retrieved 47 data
# Already retrieved 48 data
# Already retrieved 49 data
# Already retrieved 50 data
# Already retrieved 51 data
# Already retrieved 52 data
# Already retrieved 53 data
# Already retrieved 61 data
# Already retrieved 62 data
# Already retrieved 63 data
# Already retrieved 64 data
# Already retrieved 65 data
# Already retrieved 66 data
# Already retrieved 67 data
# Already retrieved 68 data
# Already retrieved 69 data
# Already retrieved 70 data
# Already retrieved 71 data
# Already retrieved 72 data
# Already retrieved 73 data
# Already retrieved 75 data
# Already retrieved 76 data
# Already retrieved 81 data
# Already retrieved 82 data
# Already retrieved 83 data
# Already retrieved 84 data
# Already retrieved 85 data
# Already retrieved 86 data
# Already retrieved 87 data
# Already retrieved 88 data
# Already retrieved 89 data
# Already retrieved 90 data
# Already retrieved 91 data
# Already retrieved 92 data
# Already retrieved 95 data
# Already retrieved 96 data
# Already retrieved 97 data
# Already retrieved 101 data
# Already retrieved 102 data
# Already retrieved 103 data
# Already retrieved 104 data
# Already retrieved 105 data
# Already retrieved 106 data
# Already retrieved 107 data
# Already retrieved 108 data
# Already retrieved 109 data
# Already retrieved 113 data
# Already retrieved 114 data
# Already retrieved 115 data
# Already retrieved 116 data
# Already retrieved 118 data
# Already retrieved 119 data
# Already retrieved 120 data
# Already retrieved 121 data
# Already retrieved 122 data
# Already retrieved 123 data
# Already retrieved 124 data
# Already retrieved 125 data
# Already retrieved 126 data
# Already retrieved 127 data
# Already retrieved 128 data
# Already retrieved 129 data
# Already retrieved 130 data
# Already retrieved 131 data
# Already retrieved 133 data
# Already retrieved 134 data
# Already retrieved 137 data
# Already retrieved 138 data
# Already retrieved 139 data
# Already retrieved 140 data
# Already retrieved 143 data
# Already retrieved 144 data
# Already retrieved 145 data
# Already retrieved 146 data
# Already retrieved 147 data
# Already retrieved 148 data
# Already retrieved 149 data
# Already retrieved 150 data
# Already retrieved 151 data
# Already retrieved 154 data
# Already retrieved 155 data
# Already retrieved 156 data
# Already retrieved 161 data
# Already retrieved 162 data
# Already retrieved 163 data
# Already retrieved 164 data
# Already retrieved 165 data
# Already retrieved 167 data
# Already retrieved 168 data
# Already retrieved 169 data
# Already retrieved 174 data
# Already retrieved 178 data
# Already retrieved 179 data
# Already retrieved 180 data
# Already retrieved 181 data
# Already retrieved 182 data
# Already retrieved 183 data
# Already retrieved 184 data
# Already retrieved 185 data
# Already retrieved 186 data
# Already retrieved 188 data
# Already retrieved 202 data
# Already retrieved 203 data
# Already retrieved 204 data
# Already retrieved 205 data
# Already retrieved 206 data
# Already retrieved 207 data
# Saved dates for 208: 181 ASC, 138 DESC
# Saved dates for 209: 181 ASC, 138 DESC
# Saved dates for 210: 181 ASC, 138 DESC
# Saved dates for 211: 92 ASC, 138 DESC
# Saved dates for 212: 92 ASC, 138 DESC
# Saved dates for 213: 92 ASC, 138 DESC
# Saved dates for 218: 89 ASC, 287 DESC
# Saved dates for 219: 89 ASC, 287 DESC
# Saved dates for 220: 89 ASC, 287 DESC
# Saved dates for 221: 89 ASC, 138 DESC
# Saved dates for 222: 89 ASC, 138 DESC
# Saved dates for 223: 89 ASC, 138 DESC
# Saved dates for 224: 181 ASC, 138 DESC
# Saved dates for 225: 181 ASC, 138 DESC
# Saved dates for 226: 92 ASC, 138 DESC
# Saved dates for 229: 92 ASC, 138 DESC
# Saved dates for 232: 89 ASC, 287 DESC
# Saved dates for 233: 89 ASC, 287 DESC
# Saved dates for 234: 89 ASC, 287 DESC
# Saved dates for 235: 89 ASC, 138 DESC
# Saved dates for 236: 89 ASC, 138 DESC
# Saved dates for 237: 181 ASC, 138 DESC
# Saved dates for 238: 181 ASC, 138 DESC
# Saved dates for 239: 182 ASC, 138 DESC
# Saved dates for 240: 93 ASC, 138 DESC
# Saved dates for 241: 93 ASC, 138 DESC
# Saved dates for 243: 92 ASC, 138 DESC
# Saved dates for 244: 92 ASC, 138 DESC
# Saved dates for 247: 89 ASC, 287 DESC
# Saved dates for 248: 89 ASC, 138 DESC
# Saved dates for 249: 89 ASC, 138 DESC
# Saved dates for 250: 181 ASC, 138 DESC
# Saved dates for 251: 181 ASC, 138 DESC
# Saved dates for 256: 93 ASC, 138 DESC
# Saved dates for 259: 89 ASC, 138 DESC
# Saved dates for 260: 89 ASC, 138 DESC
# Saved dates for 261: 181 ASC, 138 DESC
# Saved dates for 262: 181 ASC, 138 DESC
# Saved dates for 263: 181 ASC, 138 DESC
# Saved dates for 264: 92 ASC, 138 DESC
# Saved dates for 266: 92 ASC, 138 DESC
# Saved dates for 267: 92 ASC, 138 DESC
# Saved dates for 268: 92 ASC, 138 DESC
# Saved dates for 271: 89 ASC, 138 DESC
# Saved dates for 272: 181 ASC, 138 DESC
# Saved dates for 273: 181 ASC, 138 DESC
# Saved dates for 274: 181 ASC, 138 DESC
# Saved dates for 275: 92 ASC, 138 DESC
# Saved dates for 276: 92 ASC, 138 DESC
# Saved dates for 278: 92 ASC, 138 DESC
# Saved dates for 279: 92 ASC, 138 DESC
# Saved dates for 283: 181 ASC, 138 DESC
# Saved dates for 284: 181 ASC, 138 DESC
# Saved dates for 285: 92 ASC, 138 DESC
# Saved dates for 286: 92 ASC, 138 DESC
# Saved dates for 287: 92 ASC, 138 DESC
# Saved dates for 290: 92 ASC, 139 DESC
# Saved dates for 293: 182 ASC, 138 DESC
# Saved dates for 294: 182 ASC, 138 DESC
# Saved dates for 295: 181 ASC, 139 DESC
# Saved dates for 296: 92 ASC, 139 DESC
# Saved dates for 297: 92 ASC, 139 DESC
# Saved dates for 298: 92 ASC, 139 DESC
# Saved dates for 299: 92 ASC, 139 DESC
# Saved dates for 300: 92 ASC, 139 DESC
# Saved dates for 301: 92 ASC, 138 DESC
# Saved dates for 302: 92 ASC, 138 DESC
# Saved dates for 304: 182 ASC, 139 DESC
# Saved dates for 305: 182 ASC, 139 DESC
# Saved dates for 306: 182 ASC, 139 DESC
# Saved dates for 307: 92 ASC, 138 DESC
# Saved dates for 308: 92 ASC, 138 DESC
# Saved dates for 309: 92 ASC, 138 DESC
# Saved dates for 310: 92 ASC, 138 DESC
# Saved dates for 311: 92 ASC, 138 DESC
# Saved dates for 312: 92 ASC, 138 DESC
# Saved dates for 316: 182 ASC, 138 DESC
# Saved dates for 317: 182 ASC, 138 DESC
# Saved dates for 318: 92 ASC, 138 DESC
# Saved dates for 319: 92 ASC, 138 DESC
# Saved dates for 320: 92 ASC, 138 DESC
# Saved dates for 322: 92 ASC, 138 DESC
# Saved dates for 323: 92 ASC, 138 DESC
# Saved dates for 329: 182 ASC, 138 DESC
# Saved dates for 330: 182 ASC, 138 DESC
# Saved dates for 331: 92 ASC, 138 DESC
# Saved dates for 332: 92 ASC, 138 DESC
# Saved dates for 339: 181 ASC, 289 DESC
# Saved dates for 340: 181 ASC, 138 DESC
# Saved dates for 341: 92 ASC, 138 DESC
# Saved dates for 342: 92 ASC, 138 DESC
# Saved dates for 343: 92 ASC, 138 DESC
# Saved dates for 350: 181 ASC, 292 DESC
# Saved dates for 351: 181 ASC, 141 DESC
# Saved dates for 352: 91 ASC, 141 DESC
# Saved dates for 353: 91 ASC, 141 DESC
# Saved dates for 354: 91 ASC, 141 DESC
# Saved dates for 355: 92 ASC, 141 DESC
# Saved dates for 357: 92 ASC, 141 DESC
# Saved dates for 358: 92 ASC, 141 DESC
# Saved dates for 362: 181 ASC, 141 DESC
# Saved dates for 363: 91 ASC, 141 DESC
# Saved dates for 364: 91 ASC, 141 DESC
# Saved dates for 365: 91 ASC, 141 DESC
# Saved dates for 366: 91 ASC, 141 DESC
# Saved dates for 368: 91 ASC, 141 DESC
# Saved dates for 369: 91 ASC, 141 DESC
# Saved dates for 373: 182 ASC, 141 DESC
# Saved dates for 374: 91 ASC, 141 DESC
# Saved dates for 376: 91 ASC, 141 DESC
# Saved dates for 377: 91 ASC, 141 DESC
# Saved dates for 379: 91 ASC, 141 DESC
# Saved dates for 381: 182 ASC, 292 DESC
# Saved dates for 382: 182 ASC, 292 DESC
# Saved dates for 383: 182 ASC, 141 DESC
# Saved dates for 384: 91 ASC, 146 DESC
# Saved dates for 385: 91 ASC, 146 DESC
# Saved dates for 389: 91 ASC, 146 DESC
# Saved dates for 390: 182 ASC, 297 DESC
# Saved dates for 392: 91 ASC, 297 DESC
# Saved dates for 398: 91 ASC, 146 DESC
# Saved dates for 399: 182 ASC, 297 DESC
# Saved dates for 400: 182 ASC, 297 DESC
# Saved dates for 401: 91 ASC, 297 DESC
# Saved dates for 406: 91 ASC, 92 DESC
# Saved dates for 414: 91 ASC, 92 DESC
# Saved dates for 415: 91 ASC, 92 DESC
# Saved dates for 422: 91 ASC, 93 DESC
# Saved dates for 423: 91 ASC, 93 DESC
# Saved dates for 437: 91 ASC, 93 DESC
# Saved dates for 448: 90 ASC, 93 DESC
# Saved dates for 449: 91 ASC, 93 DESC
# Saved dates for 456: 90 ASC, 185 DESC
# Saved dates for 457: 90 ASC, 93 DESC
# Saved dates for 465: 90 ASC, 185 DESC
# Saved dates for 487: 182 ASC, 92 DESC
# Saved dates for 488: 182 ASC, 92 DESC
# Saved dates for 489: 90 ASC, 184 DESC
# Saved dates for 500: 182 ASC, 92 DESC
# Saved dates for 501: 90 ASC, 92 DESC
# Saved dates for 509: 182 ASC, 92 DESC
# Saved dates for 510: 182 ASC, 92 DESC
# Saved dates for 511: 182 ASC, 92 DESC
# Saved dates for 517: 182 ASC, 92 DESC
# Saved dates for 518: 182 ASC, 92 DESC
# Saved dates for 524: 92 ASC, 92 DESC
# Saved dates for 542: 92 ASC, 92 DESC
# Saved dates for 543: 92 ASC, 92 DESC
# Saved dates for 548: 92 ASC, 208 DESC
# Saved dates for 549: 92 ASC, 92 DESC
# Saved dates for 554: 91 ASC, 208 DESC
# Saved dates for 560: 91 ASC, 208 DESC
# Saved dates for 564: 91 ASC, 116 DESC
# Saved dates for 565: 91 ASC, 116 DESC
# Saved dates for 567: 91 ASC, 208 DESC
# Saved dates for 568: 91 ASC, 208 DESC
# Saved dates for 572: 91 ASC, 116 DESC
# Saved dates for 573: 91 ASC, 116 DESC
# Saved dates for 574: 91 ASC, 208 DESC
# Saved dates for 578: 91 ASC, 116 DESC
# Saved dates for 579: 91 ASC, 116 DESC
# Saved dates for 580: 91 ASC, 116 DESC
# Saved dates for 584: 91 ASC, 116 DESC
# Saved dates for 585: 91 ASC, 116 DESC
# Saved dates for 586: 91 ASC, 116 DESC
# Saved dates for 587: 91 ASC, 116 DESC
# Saved dates for 592: 92 ASC, 116 DESC
# Saved dates for 593: 92 ASC, 116 DESC
# Saved dates for 594: 91 ASC, 116 DESC
# Saved dates for 603: 92 ASC, 116 DESC
# Saved dates for 604: 92 ASC, 116 DESC
# Saved dates for 605: 92 ASC, 116 DESC
# Saved dates for 625: 92 ASC, 116 DESC
# Saved dates for 626: 92 ASC, 116 DESC
# Saved dates for 627: 92 ASC, 92 DESC
# Saved dates for 637: 92 ASC, 92 DESC
# Saved dates for 638: 92 ASC, 92 DESC
# Saved dates for 652: 92 ASC, 92 DESC
# Saved dates for 653: 92 ASC, 92 DESC
# Saved dates for 660: 92 ASC, 92 DESC
# Saved dates for 661: 92 ASC, 92 DESC
# Saved dates for 662: 92 ASC, 92 DESC
# Saved dates for 667: 92 ASC, 92 DESC
# Saved dates for 668: 92 ASC, 92 DESC
# Saved dates for 669: 92 ASC, 92 DESC
# Saved dates for 670: 92 ASC, 92 DESC
# Saved dates for 671: 92 ASC, 92 DESC
# Saved dates for 677: 92 ASC, 92 DESC
# Saved dates for 678: 92 ASC, 92 DESC
# Saved dates for 679: 92 ASC, 92 DESC
# Saved dates for 680: 92 ASC, 92 DESC
# Saved dates for 681: 180 ASC, 92 DESC
# Saved dates for 682: 180 ASC, 92 DESC
# Saved dates for 691: 91 ASC, 92 DESC
# Saved dates for 692: 91 ASC, 92 DESC
# Saved dates for 693: 91 ASC, 92 DESC
# Saved dates for 694: 92 ASC, 92 DESC
# Saved dates for 695: 180 ASC, 92 DESC
# Saved dates for 696: 180 ASC, 92 DESC
# Saved dates for 697: 180 ASC, 94 DESC
# Saved dates for 705: 91 ASC, 92 DESC
# Saved dates for 706: 91 ASC, 92 DESC
# Saved dates for 707: 91 ASC, 92 DESC
# Saved dates for 708: 179 ASC, 92 DESC
# Saved dates for 709: 179 ASC, 92 DESC
# Saved dates for 710: 179 ASC, 94 DESC
# Saved dates for 716: 89 ASC, 92 DESC
# Saved dates for 717: 89 ASC, 92 DESC
# Saved dates for 719: 89 ASC, 92 DESC
# Saved dates for 720: 89 ASC, 92 DESC
# Saved dates for 721: 89 ASC, 92 DESC
# Saved dates for 722: 179 ASC, 92 DESC
# Saved dates for 723: 179 ASC, 92 DESC
# Saved dates for 724: 179 ASC, 94 DESC
# Saved dates for 725: 88 ASC, 94 DESC
# Saved dates for 733: 91 ASC, 88 DESC
# Saved dates for 741: 89 ASC, 92 DESC
# Saved dates for 742: 89 ASC, 92 DESC
# Saved dates for 743: 89 ASC, 92 DESC
# Saved dates for 744: 89 ASC, 92 DESC
# Saved dates for 745: 177 ASC, 92 DESC
# Saved dates for 746: 177 ASC, 92 DESC
# Saved dates for 747: 177 ASC, 94 DESC
# Saved dates for 761: 92 ASC, 149 DESC
# Saved dates for 762: 92 ASC, 149 DESC
# Saved dates for 767: 180 ASC, 88 DESC
# Saved dates for 773: 89 ASC, 92 DESC
# Saved dates for 774: 89 ASC, 92 DESC
# Saved dates for 775: 89 ASC, 92 DESC
# Saved dates for 776: 89 ASC, 92 DESC
# Saved dates for 777: 176 ASC, 92 DESC
# Saved dates for 778: 176 ASC, 92 DESC
# Saved dates for 779: 177 ASC, 92 DESC
# Saved dates for 780: 177 ASC, 94 DESC
# Saved dates for 793: 91 ASC, 88 DESC
# Saved dates for 794: 180 ASC, 88 DESC
# Saved dates for 795: 180 ASC, 88 DESC
# Saved dates for 801: 89 ASC, 92 DESC
# Saved dates for 802: 89 ASC, 92 DESC
# Saved dates for 803: 89 ASC, 92 DESC
# Saved dates for 804: 89 ASC, 92 DESC
# Saved dates for 805: 176 ASC, 92 DESC
# Saved dates for 806: 176 ASC, 92 DESC
# Saved dates for 807: 176 ASC, 92 DESC
# Saved dates for 808: 176 ASC, 92 DESC
# Saved dates for 809: 87 ASC, 93 DESC
# Saved dates for 818: 91 ASC, 176 DESC
# Saved dates for 826: 180 ASC, 88 DESC
# Saved dates for 830: 89 ASC, 91 DESC
# Saved dates for 831: 89 ASC, 91 DESC
# Saved dates for 832: 89 ASC, 91 DESC
# Saved dates for 833: 89 ASC, 91 DESC
# Saved dates for 834: 176 ASC, 91 DESC
# Saved dates for 835: 176 ASC, 91 DESC
# Saved dates for 836: 176 ASC, 91 DESC
# Saved dates for 837: 87 ASC, 91 DESC
# Saved dates for 838: 87 ASC, 93 DESC
# Saved dates for 855: 89 ASC, 42 DESC
# Saved dates for 859: 89 ASC, 91 DESC
# Saved dates for 862: 89 ASC, 91 DESC
# Saved dates for 864: 176 ASC, 91 DESC
# Saved dates for 868: 87 ASC, 93 DESC
# Saved dates for 906: 182 ASC, 42 DESC
# Saved dates for 943: 91 ASC, 88 DESC
# Saved dates for 950: 91 ASC, 130 DESC
# Saved dates for 956: 181 ASC, 42 DESC
# Saved dates for 980: 91 ASC, 42 DESC
# Saved dates for 981: 91 ASC, 42 DESC
# Saved dates for 982: 181 ASC, 42 DESC
# Saved dates for 986: 181 ASC, 42 DESC
# Saved dates for 1000: 87 ASC, 91 DESC
# Saved dates for 1004: 91 ASC, 130 DESC
# Saved dates for 1005: 91 ASC, 42 DESC
# Saved dates for 1007: 181 ASC, 42 DESC
# Saved dates for 1010: 181 ASC, 42 DESC
# Saved dates for 1011: 90 ASC, 42 DESC
# Saved dates for 1022: 177 ASC, 91 DESC
# Saved dates for 1028: 90 ASC, 130 DESC
# Saved dates for 1029: 90 ASC, 130 DESC
# Saved dates for 1030: 90 ASC, 42 DESC
# Saved dates for 1031: 181 ASC, 42 DESC
# Saved dates for 1033: 92 ASC, 149 DESC
# Saved dates for 1036: 92 ASC, 149 DESC
# Saved dates for 1037: 92 ASC, 149 DESC
# Saved dates for 1038: 92 ASC, 149 DESC
# Saved dates for 1045: 180 ASC, 42 DESC
# Saved dates for 1047: 90 ASC, 42 DESC
# Saved dates for 1063: 90 ASC, 42 DESC
# Saved dates for 1084: 92 ASC, 149 DESC
# Saved dates for 1086: 92 ASC, 149 DESC
# Saved dates for 1087: 92 ASC, 149 DESC
# Saved dates for 1088: 92 ASC, 149 DESC
# Saved dates for 1089: 92 ASC, 149 DESC
# Saved dates for 1090: 92 ASC, 149 DESC
# Saved dates for 1097: 92 ASC, 149 DESC
# Saved dates for 1098: 92 ASC, 149 DESC
# Saved dates for 1099: 92 ASC, 149 DESC
# Saved dates for 1100: 92 ASC, 149 DESC
# Saved dates for 1101: 92 ASC, 149 DESC
# Saved dates for 1102: 92 ASC, 149 DESC
# Saved dates for 1103: 92 ASC, 149 DESC
# Saved dates for 1104: 181 ASC, 150 DESC

# %%
import rasterio 
import numpy as np
import pandas as pd
import re
import os
import csv
import geopandas as gpd
from rasterio.transform import rowcol  
from datetime import datetime, timedelta

# %% [markdown]
# ### Get locations of each  points

# %%
region = 'china'

# %%
shapefile_path = f'{region}/{region}_points/{region}_points.shp'

gdf = gpd.read_file(shapefile_path)

print(gdf.head())
# Out:
#    id         lon        lat                    geometry
# 0   1  109.088892  28.192974  POINT (109.08889 28.19297)
# 1   2  109.095495  28.180645   POINT (109.0955 28.18064)
# 2   3  109.094058  28.172290  POINT (109.09406 28.17229)
# 3   4  109.095406  28.165912  POINT (109.09541 28.16591)
# 4   5  109.093878  28.152527  POINT (109.09388 28.15253)

# %%
gdf['latitude'] = gdf.geometry.y
gdf['longitude'] = gdf.geometry.x

# Convert the GeoDataFrame to a DataFrame
df = pd.DataFrame(gdf.drop(columns='geometry'))
# Save the dataframe to a CSV file
csv_file_path = f'{region}/{region}_points/{region}_points.csv'
df = df.rename(columns = {'field_1': 'id'})
df.to_csv(csv_file_path, index=False)

# %% [markdown]
# ### Get pixels' values of points

# %%
tiff_folder = f'{region}/{region}_tif'
csv_file = f'{region}/{region}_points/{region}_points.csv'
s1_date_csv = f'{region}/{region}_s1_metadata.csv'
station_df = pd.read_csv(csv_file)
s1_date = pd.read_csv(s1_date_csv)
count = 1
if not {'id', 'latitude', 'longitude'}.issubset(station_df.columns):
    raise ValueError("CSV file must contain 'id', 'latitude', and 'longitude' columns.")

results = []

for image in os.listdir(tiff_folder):
    if not image.endswith('.tiff'):
        continue
    date = re.search(r'(\d{4}-\d{2}-\d{2})', image)
    date = date.group(1) if date else None

    if date is None:
        continue  
    
    date_obj = datetime.strptime(date, '%Y-%m-%d')
    previous_date = (date_obj - timedelta(days=1)).strftime('%Y-%m-%d')

    # Check if the previous date's image exists in the folder 
    if previous_date in s1_date['date'].values:
        date = previous_date
        # print('date is changed to previous date:', date)
    else:
        print('There is data for S1 for this date:', date)

    tiff_path = os.path.join(tiff_folder, image)
    with rasterio.open(tiff_path) as src:
        transform = src.transform
        
        for _, row in station_df.iterrows():
            latitude = row['latitude']
            longitude = row['longitude']

            station_id = row['id']

            # Convert latitude and longitude to row and column indices
            try:
                row_index, col_index = rowcol(transform, longitude, latitude)
                quality_flag = src.read(1)[row_index, col_index]
                if quality_flag != 0:
                    # print(f"Quality flag for {station_id} on {date}: {quality_flag}")
                    pixel_value = np.nan
                    count += 1
                    continue
                pixel_value = src.read(2)[row_index, col_index] 
                # print(f"Pixel value for {station_id} on {date}: {pixel_value}")
                sm_25 = round(pixel_value * 2, 5) 
            except IndexError:
                # print('Ohh no! The pixel is out of bounds for the image.')
                pixel_value = np.nan 
            
            results.append({
                'id': int(station_id),
                'date': date,
                'latitude': latitude,
                'longitude': longitude,
                'pixel_value': pixel_value,
                'sm': sm_25
            }) 

# Convert results to DataFrame 
results_df = pd.DataFrame(results)
# Save results to CSV
output_csv_path = f'{region}/{region}_swc_values.csv'

results_df.to_csv(output_csv_path, index=False)
# Out:
# There is data for S1 for this date: 2021-02-12
# There is data for S1 for this date: 2020-04-30
# There is data for S1 for this date: 2022-02-12
# There is data for S1 for this date: 2021-06-12
# There is data for S1 for this date: 2022-03-08
# There is data for S1 for this date: 2020-11-08
# There is data for S1 for this date: 2021-04-25
# There is data for S1 for this date: 2020-07-16
# There is data for S1 for this date: 2020-12-26
# There is data for S1 for this date: 2022-10-10
# There is data for S1 for this date: 2020-01-01
# There is data for S1 for this date: 2021-07-30
# There is data for S1 for this date: 2021-04-06
# There is data for S1 for this date: 2022-03-03
# There is data for S1 for this date: 2021-09-21
# There is data for S1 for this date: 2021-11-03
# There is data for S1 for this date: 2020-03-13
# There is data for S1 for this date: 2020-02-18
# There is data for S1 for this date: 2020-09-26
# There is data for S1 for this date: 2022-06-07
# There is data for S1 for this date: 2021-12-21
# There is data for S1 for this date: 2021-03-08
# There is data for S1 for this date: 2020-05-29
# There is data for S1 for this date: 2020-12-31
# There is data for S1 for this date: 2021-05-19
# There is data for S1 for this date: 2020-01-25
# There is data for S1 for this date: 2020-11-13
# There is data for S1 for this date: 2020-05-24
# There is data for S1 for this date: 2022-04-20
# There is data for S1 for this date: 2020-06-22
# There is data for S1 for this date: 2020-09-02
# There is data for S1 for this date: 2022-10-29
# There is data for S1 for this date: 2022-05-19
# There is data for S1 for this date: 2020-03-18
# There is data for S1 for this date: 2021-11-27
# There is data for S1 for this date: 2020-07-11
# There is data for S1 for this date: 2021-08-23
# There is data for S1 for this date: 2021-04-30
# There is data for S1 for this date: 2020-04-11
# There is data for S1 for this date: 2020-08-04
# There is data for S1 for this date: 2022-04-01
# There is data for S1 for this date: 2020-01-06
# There is data for S1 for this date: 2021-10-15
# There is data for S1 for this date: 2022-02-07
# There is data for S1 for this date: 2020-12-02
# There is data for S1 for this date: 2020-06-17
# There is data for S1 for this date: 2022-11-22
# There is data for S1 for this date: 2022-01-14
# There is data for S1 for this date: 2021-07-11
# There is data for S1 for this date: 2020-09-21
# There is data for S1 for this date: 2022-12-16
# There is data for S1 for this date: 2022-01-19
# There is data for S1 for this date: 2020-02-23
# There is data for S1 for this date: 2021-05-24
# There is data for S1 for this date: 2020-12-07
# There is data for S1 for this date: 2020-04-06
# There is data for S1 for this date: 2020-08-28
# There is data for S1 for this date: 2020-08-09
# There is data for S1 for this date: 2020-10-15
# There is data for S1 for this date: 2020-10-20
# There is data for S1 for this date: 2021-08-04
# There is data for S1 for this date: 2021-02-17
# There is data for S1 for this date: 2021-06-17
# There is data for S1 for this date: 2021-09-16
# There is data for S1 for this date: 2021-01-24
# There is data for S1 for this date: 2022-07-30
# There is data for S1 for this date: 2020-05-05
# There is data for S1 for this date: 2021-07-06
# There is data for S1 for this date: 2020-01-30
# There is data for S1 for this date: 2021-10-10
# There is data for S1 for this date: 2021-03-13
# There is data for S1 for this date: 2021-01-19

# %% [markdown]
# ### Get infomation of each site (value, location)

# %%
network = 'CHINA'

def create_site_info(input_csv, output_csv):
    # Read the existing csv with soil water content data
    df = pd.read_csv(input_csv)

    # Select unique locations 
    site_df = df[['id', 'latitude', 'longitude']].drop_duplicates().sort_values(by = 'id')

    # Add 'Network' and 'station' columns 
    site_df['network'] = network
    site_df['station'] =  site_df['id']
    site_df['s_depth'] = 0 
    site_df['e_depth'] = 5

    site_df = site_df[['network', 'station', 'latitude', 'longitude', 's_depth', 'e_depth']].rename(columns = {'latitude': 'lat', 'longitude': 'lon'})
    site_df.to_csv(output_csv, index=False)
    print(f'Site info save to {output_csv}')

# %%
input_csv = f'{region}/{region}_swc_values.csv'
output_csv = f'{region}/{region}_site_info.csv'
create_site_info(input_csv, output_csv)
# Out:
# Site info save to china/china_site_info.csv

# %%
from datetime import datetime 
import os 

def create_data_csv_files(input_csv, output_folder):
    df = pd.read_csv(input_csv)

    df['time'] = pd.to_datetime(df['date'])

    # Extract Day of Year  
    df['DoY'] = df['time'].dt.dayofyear

    # Create station column
    df['station'] = df['id']

    # Ensure output directory exists 
    os.makedirs(output_folder, exist_ok=True)

    for station, station_df in df.groupby('station'):
        station_file = os.path.join(output_folder, f'{int(station)}.csv')
        
        # Select required columns and save 
        station_df['sm_count'] = 1
        station_df.to_csv(station_file, index = False)

        print(f"Save: {station_file}")

# %%
input_csv = f'{region}/{region}_swc_values.csv'
output_folder = f'{region}/{region}_cvs'
create_data_csv_files(input_csv, output_folder)
# Out:
# Save: china/china_cvs/1.csv
# Save: china/china_cvs/2.csv
# Save: china/china_cvs/3.csv
# Save: china/china_cvs/4.csv
# Save: china/china_cvs/5.csv
# Save: china/china_cvs/6.csv
# Save: china/china_cvs/8.csv
# Save: china/china_cvs/9.csv
# Save: china/china_cvs/10.csv
# Save: china/china_cvs/11.csv
# Save: china/china_cvs/12.csv
# Save: china/china_cvs/13.csv
# Save: china/china_cvs/14.csv
# Save: china/china_cvs/15.csv
# Save: china/china_cvs/16.csv
# Save: china/china_cvs/17.csv
# Save: china/china_cvs/18.csv
# Save: china/china_cvs/19.csv
# Save: china/china_cvs/20.csv
# Save: china/china_cvs/21.csv
# Save: china/china_cvs/22.csv
# Save: china/china_cvs/23.csv
# Save: china/china_cvs/24.csv
# Save: china/china_cvs/25.csv
# Save: china/china_cvs/26.csv
# Save: china/china_cvs/27.csv
# Save: china/china_cvs/28.csv
# Save: china/china_cvs/29.csv
# Save: china/china_cvs/30.csv
# Save: china/china_cvs/31.csv
# Save: china/china_cvs/32.csv
# Save: china/china_cvs/33.csv
# Save: china/china_cvs/36.csv
# Save: china/china_cvs/37.csv
# Save: china/china_cvs/38.csv
# Save: china/china_cvs/39.csv
# Save: china/china_cvs/40.csv
# Save: china/china_cvs/41.csv
# Save: china/china_cvs/42.csv
# Save: china/china_cvs/43.csv
# Save: china/china_cvs/44.csv
# Save: china/china_cvs/45.csv
# Save: china/china_cvs/46.csv
# Save: china/china_cvs/47.csv
# Save: china/china_cvs/48.csv
# Save: china/china_cvs/49.csv
# Save: china/china_cvs/50.csv
# Save: china/china_cvs/51.csv
# Save: china/china_cvs/52.csv
# Save: china/china_cvs/53.csv
# Save: china/china_cvs/54.csv
# Save: china/china_cvs/55.csv
# Save: china/china_cvs/56.csv
# Save: china/china_cvs/57.csv
# Save: china/china_cvs/58.csv
# Save: china/china_cvs/59.csv
# Save: china/china_cvs/62.csv
# Save: china/china_cvs/64.csv
# Save: china/china_cvs/65.csv
# Save: china/china_cvs/66.csv
# Save: china/china_cvs/67.csv
# Save: china/china_cvs/68.csv
# Save: china/china_cvs/69.csv
# Save: china/china_cvs/70.csv
# Save: china/china_cvs/71.csv
# Save: china/china_cvs/72.csv
# Save: china/china_cvs/73.csv
# Save: china/china_cvs/74.csv
# Save: china/china_cvs/75.csv
# Save: china/china_cvs/76.csv
# Save: china/china_cvs/77.csv
# Save: china/china_cvs/78.csv
# Save: china/china_cvs/79.csv
# Save: china/china_cvs/80.csv
# Save: china/china_cvs/81.csv
# Save: china/china_cvs/82.csv
# Save: china/china_cvs/83.csv
# Save: china/china_cvs/84.csv
# Save: china/china_cvs/85.csv
# Save: china/china_cvs/86.csv
# Save: china/china_cvs/87.csv
# Save: china/china_cvs/89.csv
# Save: china/china_cvs/90.csv
# Save: china/china_cvs/91.csv
# Save: china/china_cvs/92.csv
# Save: china/china_cvs/93.csv
# Save: china/china_cvs/94.csv
# Save: china/china_cvs/95.csv
# Save: china/china_cvs/96.csv
# Save: china/china_cvs/97.csv
# Save: china/china_cvs/98.csv
# Save: china/china_cvs/99.csv
# Save: china/china_cvs/100.csv
# Save: china/china_cvs/101.csv
# Save: china/china_cvs/102.csv
# Save: china/china_cvs/103.csv
# Save: china/china_cvs/104.csv
# Save: china/china_cvs/105.csv
# Save: china/china_cvs/106.csv
# Save: china/china_cvs/107.csv
# Save: china/china_cvs/109.csv
# Save: china/china_cvs/110.csv
# Save: china/china_cvs/112.csv
# Save: china/china_cvs/113.csv
# Save: china/china_cvs/115.csv
# Save: china/china_cvs/116.csv
# Save: china/china_cvs/117.csv
# Save: china/china_cvs/118.csv
# Save: china/china_cvs/119.csv
# Save: china/china_cvs/120.csv
# Save: china/china_cvs/121.csv
# Save: china/china_cvs/122.csv
# Save: china/china_cvs/123.csv
# Save: china/china_cvs/124.csv
# Save: china/china_cvs/125.csv
# Save: china/china_cvs/126.csv
# Save: china/china_cvs/127.csv
# Save: china/china_cvs/128.csv
# Save: china/china_cvs/129.csv
# Save: china/china_cvs/130.csv
# Save: china/china_cvs/131.csv
# Save: china/china_cvs/132.csv
# Save: china/china_cvs/133.csv
# Save: china/china_cvs/134.csv
# Save: china/china_cvs/137.csv
# Save: china/china_cvs/138.csv
# Save: china/china_cvs/139.csv
# Save: china/china_cvs/140.csv
# Save: china/china_cvs/141.csv
# Save: china/china_cvs/142.csv
# Save: china/china_cvs/143.csv
# Save: china/china_cvs/144.csv
# Save: china/china_cvs/145.csv
# Save: china/china_cvs/146.csv
# Save: china/china_cvs/147.csv
# Save: china/china_cvs/148.csv
# Save: china/china_cvs/149.csv
# Save: china/china_cvs/150.csv
# Save: china/china_cvs/151.csv
# Save: china/china_cvs/152.csv
# Save: china/china_cvs/154.csv
# Save: china/china_cvs/155.csv
# Save: china/china_cvs/156.csv
# Save: china/china_cvs/157.csv
# Save: china/china_cvs/158.csv
# Save: china/china_cvs/160.csv
# Save: china/china_cvs/161.csv
# Save: china/china_cvs/162.csv
# Save: china/china_cvs/163.csv
# Save: china/china_cvs/164.csv
# Save: china/china_cvs/165.csv
# Save: china/china_cvs/166.csv
# Save: china/china_cvs/167.csv
# Save: china/china_cvs/168.csv
# Save: china/china_cvs/169.csv
# Save: china/china_cvs/170.csv
# Save: china/china_cvs/171.csv
# Save: china/china_cvs/172.csv
# Save: china/china_cvs/173.csv
# Save: china/china_cvs/174.csv
# Save: china/china_cvs/175.csv
# Save: china/china_cvs/176.csv
# Save: china/china_cvs/177.csv
# Save: china/china_cvs/179.csv
# Save: china/china_cvs/180.csv
# Save: china/china_cvs/181.csv
# Save: china/china_cvs/182.csv
# Save: china/china_cvs/184.csv
# Save: china/china_cvs/185.csv
# Save: china/china_cvs/188.csv
# Save: china/china_cvs/189.csv
# Save: china/china_cvs/190.csv
# Save: china/china_cvs/191.csv
# Save: china/china_cvs/192.csv
# Save: china/china_cvs/193.csv
# Save: china/china_cvs/194.csv
# Save: china/china_cvs/195.csv
# Save: china/china_cvs/196.csv
# Save: china/china_cvs/197.csv
# Save: china/china_cvs/198.csv
# Save: china/china_cvs/199.csv
# Save: china/china_cvs/200.csv
# Save: china/china_cvs/205.csv
# Save: china/china_cvs/209.csv
# Save: china/china_cvs/210.csv
# Save: china/china_cvs/212.csv
# Save: china/china_cvs/213.csv
# Save: china/china_cvs/214.csv
# Save: china/china_cvs/215.csv
# Save: china/china_cvs/216.csv
# Save: china/china_cvs/217.csv
# Save: china/china_cvs/218.csv
# Save: china/china_cvs/219.csv
# Save: china/china_cvs/220.csv
# Save: china/china_cvs/221.csv
# Save: china/china_cvs/222.csv
# Save: china/china_cvs/223.csv
# Save: china/china_cvs/224.csv
# Save: china/china_cvs/225.csv
# Save: china/china_cvs/236.csv
# Save: china/china_cvs/237.csv
# Save: china/china_cvs/238.csv
# Save: china/china_cvs/239.csv
# Save: china/china_cvs/240.csv
# Save: china/china_cvs/241.csv
# Save: china/china_cvs/242.csv
# Save: china/china_cvs/243.csv
# Save: china/china_cvs/244.csv
# Save: china/china_cvs/245.csv
# Save: china/china_cvs/246.csv
# Save: china/china_cvs/247.csv
# Save: china/china_cvs/248.csv
# Save: china/china_cvs/249.csv
# Save: china/china_cvs/250.csv
# Save: china/china_cvs/259.csv
# Save: china/china_cvs/260.csv
# Save: china/china_cvs/261.csv
# Save: china/china_cvs/262.csv
# Save: china/china_cvs/263.csv
# Save: china/china_cvs/264.csv
# Save: china/china_cvs/265.csv
# Save: china/china_cvs/266.csv
# Save: china/china_cvs/267.csv
# Save: china/china_cvs/268.csv
# Save: china/china_cvs/269.csv
# Save: china/china_cvs/270.csv
# Save: china/china_cvs/271.csv
# Save: china/china_cvs/272.csv
# Save: china/china_cvs/273.csv
# Save: china/china_cvs/274.csv
# Save: china/china_cvs/275.csv
# Save: china/china_cvs/276.csv
# Save: china/china_cvs/280.csv
# Save: china/china_cvs/281.csv
# Save: china/china_cvs/282.csv
# Save: china/china_cvs/283.csv
# Save: china/china_cvs/284.csv
# Save: china/china_cvs/285.csv
# Save: china/china_cvs/286.csv
# Save: china/china_cvs/287.csv
# Save: china/china_cvs/288.csv
# Save: china/china_cvs/289.csv
# Save: china/china_cvs/290.csv
# Save: china/china_cvs/291.csv
# Save: china/china_cvs/292.csv
# Save: china/china_cvs/293.csv
# Save: china/china_cvs/294.csv
# Save: china/china_cvs/295.csv
# Save: china/china_cvs/296.csv
# Save: china/china_cvs/297.csv
# Save: china/china_cvs/298.csv
# Save: china/china_cvs/299.csv
# Save: china/china_cvs/300.csv
# Save: china/china_cvs/301.csv
# Save: china/china_cvs/302.csv
# Save: china/china_cvs/305.csv
# Save: china/china_cvs/306.csv
# Save: china/china_cvs/307.csv
# Save: china/china_cvs/308.csv
# Save: china/china_cvs/309.csv
# Save: china/china_cvs/310.csv
# Save: china/china_cvs/311.csv
# Save: china/china_cvs/312.csv
# Save: china/china_cvs/313.csv
# Save: china/china_cvs/314.csv
# Save: china/china_cvs/315.csv
# Save: china/china_cvs/316.csv
# Save: china/china_cvs/317.csv
# Save: china/china_cvs/318.csv
# Save: china/china_cvs/319.csv
# Save: china/china_cvs/320.csv
# Save: china/china_cvs/321.csv
# Save: china/china_cvs/322.csv
# Save: china/china_cvs/323.csv
# Save: china/china_cvs/324.csv
# Save: china/china_cvs/325.csv
# Save: china/china_cvs/326.csv
# Save: china/china_cvs/327.csv
# Save: china/china_cvs/328.csv
# Save: china/china_cvs/329.csv
# Save: china/china_cvs/330.csv
# Save: china/china_cvs/331.csv
# Save: china/china_cvs/332.csv
# Save: china/china_cvs/333.csv
# Save: china/china_cvs/334.csv
# Save: china/china_cvs/335.csv
# Save: china/china_cvs/336.csv
# Save: china/china_cvs/337.csv
# Save: china/china_cvs/338.csv
# Save: china/china_cvs/339.csv
# Save: china/china_cvs/340.csv
# Save: china/china_cvs/341.csv
# Save: china/china_cvs/342.csv
# Save: china/china_cvs/343.csv
# Save: china/china_cvs/344.csv
# Save: china/china_cvs/345.csv
# Save: china/china_cvs/346.csv
# Save: china/china_cvs/347.csv
# Save: china/china_cvs/348.csv
# Save: china/china_cvs/349.csv
# Save: china/china_cvs/350.csv
# Save: china/china_cvs/351.csv
# Save: china/china_cvs/352.csv
# Save: china/china_cvs/354.csv
# Save: china/china_cvs/355.csv
# Save: china/china_cvs/356.csv
# Save: china/china_cvs/357.csv
# Save: china/china_cvs/358.csv
# Save: china/china_cvs/359.csv
# Save: china/china_cvs/360.csv
# Save: china/china_cvs/361.csv
# Save: china/china_cvs/362.csv
# Save: china/china_cvs/363.csv
# Save: china/china_cvs/364.csv
# Save: china/china_cvs/365.csv
# Save: china/china_cvs/366.csv
# Save: china/china_cvs/367.csv
# Save: china/china_cvs/368.csv
# Save: china/china_cvs/372.csv
# Save: china/china_cvs/373.csv
# Save: china/china_cvs/374.csv
# Save: china/china_cvs/375.csv
# Save: china/china_cvs/376.csv
# Save: china/china_cvs/378.csv
# Save: china/china_cvs/379.csv
# Save: china/china_cvs/380.csv
# Save: china/china_cvs/381.csv
# Save: china/china_cvs/382.csv
# Save: china/china_cvs/383.csv
# Save: china/china_cvs/384.csv
# Save: china/china_cvs/385.csv
# Save: china/china_cvs/386.csv
# Save: china/china_cvs/387.csv
# Save: china/china_cvs/388.csv
# Save: china/china_cvs/389.csv
# Save: china/china_cvs/390.csv
# Save: china/china_cvs/391.csv
# Save: china/china_cvs/392.csv
# Save: china/china_cvs/393.csv
# Save: china/china_cvs/394.csv
# Save: china/china_cvs/395.csv
# Save: china/china_cvs/397.csv
# Save: china/china_cvs/398.csv
# Save: china/china_cvs/399.csv
# Save: china/china_cvs/400.csv
# Save: china/china_cvs/401.csv
# Save: china/china_cvs/402.csv
# Save: china/china_cvs/403.csv
# Save: china/china_cvs/404.csv
# Save: china/china_cvs/405.csv
# Save: china/china_cvs/406.csv
# Save: china/china_cvs/407.csv
# Save: china/china_cvs/408.csv
# Save: china/china_cvs/409.csv
# Save: china/china_cvs/410.csv
# Save: china/china_cvs/411.csv
# Save: china/china_cvs/412.csv
# Save: china/china_cvs/413.csv
# Save: china/china_cvs/414.csv
# Save: china/china_cvs/415.csv
# Save: china/china_cvs/416.csv
# Save: china/china_cvs/417.csv
# Save: china/china_cvs/418.csv
# Save: china/china_cvs/419.csv
# Save: china/china_cvs/420.csv
# Save: china/china_cvs/421.csv
# Save: china/china_cvs/422.csv
# Save: china/china_cvs/423.csv
# Save: china/china_cvs/424.csv
# Save: china/china_cvs/425.csv
# Save: china/china_cvs/426.csv
# Save: china/china_cvs/427.csv
# Save: china/china_cvs/428.csv
# Save: china/china_cvs/429.csv
# Save: china/china_cvs/430.csv
# Save: china/china_cvs/431.csv
# Save: china/china_cvs/432.csv
# Save: china/china_cvs/433.csv
# Save: china/china_cvs/434.csv
# Save: china/china_cvs/435.csv
# Save: china/china_cvs/436.csv
# Save: china/china_cvs/437.csv
# Save: china/china_cvs/438.csv
# Save: china/china_cvs/439.csv
# Save: china/china_cvs/440.csv
# Save: china/china_cvs/441.csv
# Save: china/china_cvs/442.csv
# Save: china/china_cvs/443.csv
# Save: china/china_cvs/444.csv
# Save: china/china_cvs/445.csv
# Save: china/china_cvs/446.csv
# Save: china/china_cvs/447.csv
# Save: china/china_cvs/448.csv
# Save: china/china_cvs/449.csv
# Save: china/china_cvs/450.csv
# Save: china/china_cvs/451.csv
# Save: china/china_cvs/452.csv
# Save: china/china_cvs/453.csv
# Save: china/china_cvs/454.csv
# Save: china/china_cvs/455.csv
# Save: china/china_cvs/456.csv
# Save: china/china_cvs/457.csv
# Save: china/china_cvs/458.csv
# Save: china/china_cvs/459.csv
# Save: china/china_cvs/460.csv
# Save: china/china_cvs/461.csv
# Save: china/china_cvs/462.csv
# Save: china/china_cvs/463.csv
# Save: china/china_cvs/464.csv
# Save: china/china_cvs/465.csv
# Save: china/china_cvs/466.csv
# Save: china/china_cvs/467.csv
# Save: china/china_cvs/468.csv
# Save: china/china_cvs/469.csv
# Save: china/china_cvs/470.csv
# Save: china/china_cvs/471.csv
# Save: china/china_cvs/472.csv
# Save: china/china_cvs/473.csv
# Save: china/china_cvs/474.csv
# Save: china/china_cvs/475.csv
# Save: china/china_cvs/476.csv
# Save: china/china_cvs/477.csv
# Save: china/china_cvs/478.csv
# Save: china/china_cvs/479.csv
# Save: china/china_cvs/480.csv
# Save: china/china_cvs/481.csv
# Save: china/china_cvs/482.csv
# Save: china/china_cvs/483.csv
# Save: china/china_cvs/484.csv
# Save: china/china_cvs/485.csv
# Save: china/china_cvs/486.csv
# Save: china/china_cvs/487.csv
# Save: china/china_cvs/488.csv
# Save: china/china_cvs/489.csv
# Save: china/china_cvs/490.csv
# Save: china/china_cvs/491.csv
# Save: china/china_cvs/492.csv
# Save: china/china_cvs/493.csv
# Save: china/china_cvs/494.csv
# Save: china/china_cvs/495.csv
# Save: china/china_cvs/496.csv
# Save: china/china_cvs/497.csv
# Save: china/china_cvs/498.csv
# Save: china/china_cvs/499.csv
# Save: china/china_cvs/500.csv
# Save: china/china_cvs/501.csv
# Save: china/china_cvs/502.csv
# Save: china/china_cvs/503.csv
# Save: china/china_cvs/504.csv
# Save: china/china_cvs/505.csv
# Save: china/china_cvs/506.csv
# Save: china/china_cvs/507.csv
# Save: china/china_cvs/508.csv
# Save: china/china_cvs/509.csv
# Save: china/china_cvs/510.csv
# Save: china/china_cvs/511.csv
# Save: china/china_cvs/512.csv
# Save: china/china_cvs/513.csv
# Save: china/china_cvs/514.csv
# Save: china/china_cvs/515.csv
# Save: china/china_cvs/516.csv
# Save: china/china_cvs/517.csv
# Save: china/china_cvs/518.csv
# Save: china/china_cvs/519.csv
# Save: china/china_cvs/520.csv
# Save: china/china_cvs/521.csv
# Save: china/china_cvs/522.csv
# Save: china/china_cvs/523.csv
# Save: china/china_cvs/524.csv
# Save: china/china_cvs/525.csv
# Save: china/china_cvs/526.csv
# Save: china/china_cvs/527.csv
# Save: china/china_cvs/528.csv
# Save: china/china_cvs/529.csv
# Save: china/china_cvs/530.csv
# Save: china/china_cvs/531.csv
# Save: china/china_cvs/532.csv
# Save: china/china_cvs/533.csv
# Save: china/china_cvs/534.csv
# Save: china/china_cvs/535.csv
# Save: china/china_cvs/536.csv
# Save: china/china_cvs/537.csv
# Save: china/china_cvs/538.csv
# Save: china/china_cvs/539.csv
# Save: china/china_cvs/540.csv
# Save: china/china_cvs/541.csv
# Save: china/china_cvs/542.csv
# Save: china/china_cvs/543.csv
# Save: china/china_cvs/544.csv
# Save: china/china_cvs/545.csv
# Save: china/china_cvs/546.csv
# Save: china/china_cvs/547.csv
# Save: china/china_cvs/548.csv
# Save: china/china_cvs/549.csv
# Save: china/china_cvs/550.csv
# Save: china/china_cvs/551.csv
# Save: china/china_cvs/552.csv
# Save: china/china_cvs/553.csv
# Save: china/china_cvs/554.csv
# Save: china/china_cvs/555.csv
# Save: china/china_cvs/556.csv
# Save: china/china_cvs/557.csv
# Save: china/china_cvs/558.csv
# Save: china/china_cvs/559.csv
# Save: china/china_cvs/560.csv
# Save: china/china_cvs/561.csv
# Save: china/china_cvs/562.csv
# Save: china/china_cvs/563.csv
# Save: china/china_cvs/564.csv
# Save: china/china_cvs/565.csv
# Save: china/china_cvs/566.csv
# Save: china/china_cvs/567.csv
# Save: china/china_cvs/568.csv
# Save: china/china_cvs/569.csv
# Save: china/china_cvs/570.csv
# Save: china/china_cvs/571.csv
# Save: china/china_cvs/572.csv
# Save: china/china_cvs/573.csv
# Save: china/china_cvs/574.csv
# Save: china/china_cvs/575.csv
# Save: china/china_cvs/576.csv
# Save: china/china_cvs/577.csv
# Save: china/china_cvs/578.csv
# Save: china/china_cvs/579.csv
# Save: china/china_cvs/580.csv
# Save: china/china_cvs/581.csv
# Save: china/china_cvs/582.csv
# Save: china/china_cvs/583.csv
# Save: china/china_cvs/584.csv
# Save: china/china_cvs/585.csv
# Save: china/china_cvs/586.csv
# Save: china/china_cvs/587.csv
# Save: china/china_cvs/588.csv
# Save: china/china_cvs/589.csv
# Save: china/china_cvs/590.csv
# Save: china/china_cvs/591.csv
# Save: china/china_cvs/592.csv
# Save: china/china_cvs/593.csv
# Save: china/china_cvs/594.csv
# Save: china/china_cvs/595.csv
# Save: china/china_cvs/596.csv
# Save: china/china_cvs/597.csv
# Save: china/china_cvs/598.csv
# Save: china/china_cvs/599.csv
# Save: china/china_cvs/600.csv

# %%
china_sites = pd.read_csv('china/china_site_info.csv')
n = len(china_sites)

half = n//2 

china_site_1 = china_sites.iloc[:half].reset_index(drop = True)
china_site_2 = china_sites.iloc[half:].reset_index(drop = True)

china_site_1.to_csv('china/china_site_info_1.csv')
china_site_2.to_csv('china/china_site_info_2.csv')

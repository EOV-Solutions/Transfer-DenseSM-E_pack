# %%
import pandas as pd 
import numpy as np 
import os

# %%
def normalizingData(X, min_per, max_per):
    temp=(X - min_per) / (max_per - min_per)
    temp[temp>1]=1
    temp[temp<0]=0
    return temp

# %%
folder = 'input_tb/ndvi/ndvi_output'
output_folder = 'input_tb/ndvi/ndvi_normalized'
os.makedirs(output_folder, exist_ok=True)
for file in os.listdir(folder):
    print(file)
    file_path = os.path.join(folder, file)
    output_path = os.path.join(output_folder, file)

    df_ndvi = pd.read_csv(file_path)
    ndvi_normalized = normalizingData(np.asarray(df_ndvi['NDVI']), -0.2, 1.0)
    df_ndvi['NDVI'] = ndvi_normalized 

    # renamed 'Unamed: 0' column to 'date' 
    if 'Unnamed: 0' in df_ndvi.columns:
        df_ndvi = df_ndvi.rename(columns={'Unnamed: 0': 'date'})
    df_ndvi.to_csv(output_path)
# Out:
# THAIBINH_101.csv
# THAIBINH_86.csv
# THAIBINH_67.csv
# THAIBINH_14.csv
# THAIBINH_45.csv
# THAIBINH_31.csv
# THAIBINH_69.csv
# THAIBINH_22.csv
# THAIBINH_21.csv
# THAIBINH_12.csv
# THAIBINH_3.csv
# THAIBINH_16.csv
# THAIBINH_140.csv
# THAIBINH_24.csv
# THAIBINH_124.csv
# THAIBINH_78.csv
# THAIBINH_113.csv
# THAIBINH_38.csv
# THAIBINH_23.csv
# THAIBINH_139.csv
# THAIBINH_40.csv
# THAIBINH_132.csv
# THAIBINH_42.csv
# THAIBINH_111.csv
# THAIBINH_96.csv
# THAIBINH_44.csv
# THAIBINH_57.csv
# THAIBINH_71.csv
# THAIBINH_88.csv
# THAIBINH_130.csv
# THAIBINH_7.csv
# THAIBINH_65.csv
# THAIBINH_99.csv
# THAIBINH_98.csv
# THAIBINH_52.csv
# THAIBINH_62.csv
# THAIBINH_72.csv
# THAIBINH_89.csv
# THAIBINH_116.csv
# THAIBINH_83.csv
# THAIBINH_125.csv
# THAIBINH_75.csv
# THAIBINH_61.csv
# THAIBINH_150.csv
# THAIBINH_127.csv
# THAIBINH_106.csv
# THAIBINH_135.csv
# THAIBINH_80.csv
# THAIBINH_41.csv
# THAIBINH_119.csv
# THAIBINH_112.csv
# THAIBINH_108.csv
# THAIBINH_147.csv
# THAIBINH_143.csv
# THAIBINH_9.csv
# THAIBINH_81.csv
# THAIBINH_123.csv
# THAIBINH_8.csv
# THAIBINH_146.csv
# THAIBINH_29.csv
# THAIBINH_77.csv
# THAIBINH_34.csv
# THAIBINH_110.csv
# THAIBINH_73.csv
# THAIBINH_50.csv
# THAIBINH_129.csv
# THAIBINH_100.csv
# THAIBINH_51.csv
# THAIBINH_91.csv
# THAIBINH_121.csv
# THAIBINH_39.csv
# THAIBINH_43.csv
# THAIBINH_37.csv
# THAIBINH_54.csv
# THAIBINH_120.csv
# THAIBINH_109.csv
# THAIBINH_133.csv
# THAIBINH_107.csv
# THAIBINH_11.csv
# THAIBINH_46.csv
# THAIBINH_60.csv
# THAIBINH_27.csv
# THAIBINH_55.csv
# THAIBINH_19.csv
# THAIBINH_47.csv
# THAIBINH_145.csv
# THAIBINH_92.csv
# THAIBINH_105.csv
# THAIBINH_1.csv
# THAIBINH_32.csv
# THAIBINH_141.csv
# THAIBINH_128.csv
# THAIBINH_68.csv
# THAIBINH_25.csv
# THAIBINH_5.csv
# THAIBINH_90.csv
# THAIBINH_103.csv
# THAIBINH_26.csv
# THAIBINH_136.csv
# THAIBINH_115.csv
# THAIBINH_15.csv
# THAIBINH_59.csv
# THAIBINH_93.csv
# THAIBINH_122.csv
# THAIBINH_148.csv
# THAIBINH_6.csv
# THAIBINH_13.csv
# THAIBINH_79.csv
# THAIBINH_58.csv
# THAIBINH_33.csv
# THAIBINH_53.csv
# THAIBINH_17.csv
# THAIBINH_36.csv
# THAIBINH_64.csv
# THAIBINH_114.csv
# THAIBINH_35.csv
# THAIBINH_70.csv
# THAIBINH_82.csv
# THAIBINH_4.csv
# THAIBINH_28.csv
# THAIBINH_131.csv
# THAIBINH_102.csv
# THAIBINH_2.csv
# THAIBINH_76.csv
# THAIBINH_48.csv
# THAIBINH_137.csv
# THAIBINH_142.csv
# THAIBINH_126.csv
# THAIBINH_49.csv
# THAIBINH_117.csv
# THAIBINH_20.csv
# THAIBINH_84.csv
# THAIBINH_18.csv
# THAIBINH_144.csv
# THAIBINH_138.csv
# THAIBINH_118.csv
# THAIBINH_149.csv
# THAIBINH_134.csv
# THAIBINH_74.csv
# THAIBINH_85.csv
# THAIBINH_56.csv
# THAIBINH_63.csv
# THAIBINH_97.csv
# THAIBINH_66.csv
# THAIBINH_87.csv
# THAIBINH_10.csv
# THAIBINH_104.csv
# THAIBINH_94.csv
# THAIBINH_95.csv
# THAIBINH_30.csv

# %%
sm_folder = 'output_tb/output_ndvi250_first'
ndvi_normalized_folder = 'input_tb/ndvi/ndvi_normalized'
output_folder = 'input_tb/ndvi/output_tb_landsat'
os.makedirs(output_folder, exist_ok = True)

for file in os.listdir(sm_folder):
    sm_file_path = os.path.join(sm_folder, file)
    ndvi_normalized_path = os.path.join(ndvi_normalized_folder, file)

    df_sm = pd.read_csv(sm_file_path)
    df_ndvi_normalized = pd.read_csv(ndvi_normalized_path)

    df_ndvi_normalized = df_ndvi_normalized.sort_values('date').reset_index(drop = True) 

    for date in df_sm['date']:
        last_index =  df_ndvi_normalized[df_ndvi_normalized['date'] <= date].last_valid_index()

        if last_index is None or last_index < 45:
            continue 
        ndvi_values = df_ndvi_normalized.loc[(last_index - 45):last_index, 'NDVI'].values 
        idx = df_sm.index[df_sm['date'] == date] 
        if len(idx) > 0:
            df_sm.loc[idx[0], '15':'60'] = ndvi_values 

    # Export updated output file
    output_path = os.path.join(output_folder, file)
    df_sm.to_csv(output_path, index = False)

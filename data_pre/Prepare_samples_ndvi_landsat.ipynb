# %% [markdown]
# ## Prepare samples using GEE
#
# ### Setup
# For each site, extract the full time series of Sentinel-1,NDVI data from the GEE. Note: if the output csv files already exist they are assumed to be correct and are not over-written.
#
# Note: Proxy was set for the well known reason in China and you may not need it. Also check the proxy in the utils.py

# %%
import os
import pandas as pd
import numpy as np
import time
import ee
import utils_data_pre_HR

# %%
# ee.Authenticate(force = True) # authenticate the gee account
# ee.Initialize()

# %% [markdown]
# Set the parameters, paths etc.

# %%
HOME_DATA_DIR = '/mnt/data2tb/Transfer-DenseSM-E_2/1km_global_data/india' # change the dir
# Date range for Sentinel-1 data
START_DATE = "2021-01-01" #"2016-01-01" 
END_DATE =  "2022-12-31"  #"2023-11-30"  
# Date range for NDVI and weather data,one year preceding the Sentinel-1
START_DATE_NDVI = "2019-12-26" #"2019-12-26"     
END_DATE_NDVI = "2023-01-08"  #"2023-01-06" 
#Global setups, dir, path
save_to_disk = False # No temporal files
SM_SITES = os.path.join(HOME_DATA_DIR, "points/tree_grass_crops_site_info.csv") # the site informaiton extracted by Preprocessing_ISMN_Raw_Data.ipynb
dir_to_site_sm = os.path.join(HOME_DATA_DIR, "tree_grass_crops_csv") # the path to the soil moisture of stations
dir_to_site_samples = os.path.join(HOME_DATA_DIR, "ndvi/ndvi_output")
os.makedirs(dir_to_site_samples, exist_ok= True)

# %% [markdown]
# Read the sites information and determine the grid size

# %%
sites = pd.read_csv(SM_SITES, float_precision="high")
# sites = pd.read_csv('data_pre/stations.csv', float_precision="high")

# grid_size = 0.05 # km
grid_size = 1.0 #km
pobj=utils_data_pre_HR.grids_4_a_region(4326,grid_size) # determine the grid size

# %% [markdown]
# ## A loop to prepare the input data of each site
#
# ###### 1 Create the gird polygon covering a site in both EASE2.0 and WGS84
# ###### 2 Extract Sentienl-1, soil texture, terrain, NDVI, precipition, temperature etc. Check the utils for the details
# ###### 3 Concatenate all data
# ###### 4 Extract the ground soil moisture of the site
# ###### Note: the loop may report the error "IncompleteRead", just run this cell again.

# %%
sites.columns
filtered_sites = sites[sites['network'] == 'INDIA_1km'] # filter the sites by network
filtered_sites.reset_index(drop = True, inplace=True)
filtered_sites
# Out:
#        network  station        lat        lon  s_depth  e_depth
# 0    INDIA_1km        1  28.068695  77.117534        0        5
# 1    INDIA_1km        2  28.056521  77.117582        0        5
# 2    INDIA_1km        3  28.034862  77.122390        0        5
# 3    INDIA_1km        7  27.966415  77.112073        0        5
# 4    INDIA_1km        8  27.954784  77.127043        0        5
# ..         ...      ...        ...        ...      ...      ...
# 592  INDIA_1km      646  27.696755  77.610797        0        5
# 593  INDIA_1km      647  27.682648  77.621828        0        5
# 594  INDIA_1km      648  27.672665  77.615471        0        5
# 595  INDIA_1km      649  27.642475  77.622366        0        5
# 596  INDIA_1km      650  27.626054  77.608647        0        5
#
# [597 rows x 6 columns]

# %%
for i in range(len(sites)):#len(sites)
    site = sites.loc[i]
    print(f"Processing for {i}: {site['station']}")
    path_2_site_file = os.path.join(dir_to_site_samples,'%s.csv'%(site['network']+'_'+str(site['station'])))
    if os.path.exists(path_2_site_file):
        print(f"{path_2_site_file} is already done.")
        continue
    # if os.path.exists(path_2_site_file):
    #     continue
    ring_wgs,grid_ring=pobj.get_wgs_grid(site.lon,site.lat)
    polygon_grid=ee.Geometry.Polygon(ring_wgs, 'EPSG:4326', True, 20, False)
    _,_, df_NDVI,_=utils_data_pre_HR.prepare_grid_data_v1(polygon_grid,START_DATE, END_DATE,START_DATE_NDVI,END_DATE_NDVI,ring_wgs,pobj, path_2_site_file)
    time.sleep(2)
    print("Done !!!")
# Out:
# Processing for 0: 1
# Number of images: 227
# Done !!!
# Processing for 1: 2
# Number of images: 218
# Done !!!
# Processing for 2: 3
# Number of images: 204
# Done !!!
# Processing for 3: 7
# Number of images: 166
# Done !!!
# Processing for 4: 8
# Number of images: 104
# Done !!!
# Processing for 5: 9
# Number of images: 139
# Done !!!
# Processing for 6: 10
# Number of images: 112
# Done !!!
# Processing for 7: 11
# Number of images: 86
# Done !!!
# Processing for 8: 12
# Number of images: 89
# Done !!!
# Processing for 9: 13
# Number of images: 86
# Done !!!
# Processing for 10: 14
# Number of images: 86
# Done !!!
# Processing for 11: 15
# Number of images: 86
# Done !!!
# Processing for 12: 16
# Number of images: 86
# Done !!!
# Processing for 13: 17
# Number of images: 86
# Done !!!
# Processing for 14: 18
# Number of images: 86
# Done !!!
# Processing for 15: 19
# Number of images: 86
# Done !!!
# Processing for 16: 20
# Number of images: 86
# Done !!!
# Processing for 17: 21
# Number of images: 86
# Done !!!
# Processing for 18: 22
# Number of images: 86
# Done !!!
# Processing for 19: 23
# Number of images: 86
# Done !!!
# Processing for 20: 24
# Number of images: 86
# Done !!!
# Processing for 21: 25
# Number of images: 86
# Done !!!
# Processing for 22: 26
# Number of images: 86
# Done !!!
# Processing for 23: 31
# Number of images: 122
# Done !!!
# Processing for 24: 32
# Number of images: 106
# Done !!!
# Processing for 25: 33
# Number of images: 86
# Done !!!
# Processing for 26: 34
# Number of images: 86
# Done !!!
# Processing for 27: 35
# Number of images: 86
# Done !!!
# Processing for 28: 36
# Number of images: 86
# Done !!!
# Processing for 29: 37
# Number of images: 86
# Done !!!
# Processing for 30: 38
# Number of images: 86
# Done !!!
# Processing for 31: 39
# Number of images: 86
# Done !!!
# Processing for 32: 40
# Number of images: 86
# Done !!!
# Processing for 33: 41
# Number of images: 86
# Done !!!
# Processing for 34: 42
# Number of images: 86
# Done !!!
# Processing for 35: 43
# Number of images: 86
# Done !!!
# Processing for 36: 44
# Number of images: 86
# Done !!!
# Processing for 37: 45
# Number of images: 86
# Done !!!
# Processing for 38: 46
# Number of images: 86
# Done !!!
# Processing for 39: 47
# Number of images: 86
# Done !!!
# Processing for 40: 48
# Number of images: 86
# Done !!!
# Processing for 41: 49
# Number of images: 86
# Done !!!
# Processing for 42: 50
# Number of images: 86
# Done !!!
# Processing for 43: 51
# Number of images: 86
# Done !!!
# Processing for 44: 52
# Number of images: 86
# Done !!!
# Processing for 45: 55
# Number of images: 89
# Done !!!
# Processing for 46: 56
# Number of images: 86
# Done !!!
# Processing for 47: 57
# Number of images: 86
# Done !!!
# Processing for 48: 58
# Number of images: 86
# Done !!!
# Processing for 49: 59
# Number of images: 86
# Done !!!
# Processing for 50: 60
# Number of images: 86
# Done !!!
# Processing for 51: 61
# Number of images: 86
# Done !!!
# Processing for 52: 62
# Number of images: 86
# Done !!!
# Processing for 53: 63
# Number of images: 86
# Done !!!
# Processing for 54: 64
# Number of images: 86
# Done !!!
# Processing for 55: 65
# Number of images: 86
# Done !!!
# Processing for 56: 66
# Number of images: 86
# Done !!!
# Processing for 57: 67
# Number of images: 86
# Done !!!
# Processing for 58: 68
# Number of images: 86
# Done !!!
# Processing for 59: 69
# Number of images: 86
# Done !!!
# Processing for 60: 70
# Number of images: 86
# Done !!!
# Processing for 61: 71
# Number of images: 86
# Done !!!
# Processing for 62: 72
# Number of images: 86
# Done !!!
# Processing for 63: 73
# Number of images: 86
# Done !!!
# Processing for 64: 74
# Number of images: 86
# Done !!!
# Processing for 65: 75
# Number of images: 86
# Done !!!
# Processing for 66: 76
# Number of images: 86
# Done !!!
# Processing for 67: 77
# Number of images: 87
# Done !!!
# Processing for 68: 78
# Number of images: 86
# Done !!!
# Processing for 69: 79
# Number of images: 86
# Done !!!
# Processing for 70: 80
# Number of images: 86
# Done !!!
# Processing for 71: 81
# Number of images: 86
# Done !!!
# Processing for 72: 82
# Number of images: 86
# Done !!!
# Processing for 73: 83
# Number of images: 86
# Done !!!
# Processing for 74: 84
# Number of images: 86
# Done !!!
# Processing for 75: 85
# Number of images: 86
# Done !!!
# Processing for 76: 86
# Number of images: 86
# Done !!!
# Processing for 77: 87
# Number of images: 86
# Done !!!
# Processing for 78: 88
# Number of images: 86
# Done !!!
# Processing for 79: 89
# Number of images: 86
# Done !!!
# Processing for 80: 90
# Number of images: 86
# Done !!!
# Processing for 81: 91
# Number of images: 86
# Done !!!
# Processing for 82: 92
# Number of images: 86
# Done !!!
# Processing for 83: 93
# Number of images: 86
# Done !!!
# Processing for 84: 96
# Number of images: 86
# Done !!!
# Processing for 85: 97
# Number of images: 86
# Done !!!
# Processing for 86: 98
# Number of images: 87
# Done !!!
# Processing for 87: 99
# Number of images: 87
# Done !!!
# Processing for 88: 100
# Number of images: 87
# Done !!!
# Processing for 89: 101
# Number of images: 87
# Done !!!
# Processing for 90: 102
# Number of images: 87
# Done !!!
# Processing for 91: 103
# Number of images: 87
# Done !!!
# Processing for 92: 104
# Number of images: 87
# Done !!!
# Processing for 93: 105
# Number of images: 86
# Done !!!
# Processing for 94: 106
# Number of images: 86
# Done !!!
# Processing for 95: 107
# Number of images: 86
# Done !!!
# Processing for 96: 108
# Number of images: 86
# Done !!!
# Processing for 97: 109
# Number of images: 86
# Done !!!
# Processing for 98: 110
# Number of images: 86
# Done !!!
# Processing for 99: 111
# Number of images: 86
# Done !!!
# Processing for 100: 112
# Number of images: 86
# Done !!!
# Processing for 101: 113
# Number of images: 86
# Done !!!
# Processing for 102: 114
# Number of images: 86
# Done !!!
# Processing for 103: 115
# Number of images: 86
# Done !!!
# Processing for 104: 116
# Number of images: 86
# Done !!!
# Processing for 105: 118
# Number of images: 86
# Done !!!
# Processing for 106: 119
# Number of images: 87
# Done !!!
# Processing for 107: 121
# Number of images: 86
# Done !!!
# Processing for 108: 122
# Number of images: 87
# Done !!!
# Processing for 109: 123
# Number of images: 87
# Done !!!
# Processing for 110: 124
# Number of images: 87
# Done !!!
# Processing for 111: 125
# Number of images: 87
# Done !!!
# Processing for 112: 126
# Number of images: 87
# Done !!!
# Processing for 113: 127
# Number of images: 87
# Done !!!
# Processing for 114: 128
# Number of images: 87
# Done !!!
# Processing for 115: 129
# Number of images: 87
# Done !!!
# Processing for 116: 130
# Number of images: 87
# Done !!!
# Processing for 117: 131
# Number of images: 86
# Done !!!
# Processing for 118: 132
# Number of images: 86
# Done !!!
# Processing for 119: 133
# Number of images: 86
# Done !!!
# Processing for 120: 134
# Number of images: 86
# Done !!!
# Processing for 121: 135
# Number of images: 86
# Done !!!
# Processing for 122: 136
# Number of images: 86
# Done !!!
# Processing for 123: 137
# Number of images: 86
# Done !!!
# Processing for 124: 138
# Number of images: 86
# Done !!!
# Processing for 125: 139
# Number of images: 86
# Done !!!
# Processing for 126: 140
# Number of images: 87
# Done !!!
# Processing for 127: 141
# Number of images: 87
# Done !!!
# Processing for 128: 142
# Number of images: 87
# Done !!!
# Processing for 129: 143
# Number of images: 87
# Done !!!
# Processing for 130: 144
# Number of images: 87
# Done !!!
# Processing for 131: 145
# Number of images: 87
# Done !!!
# Processing for 132: 146
# Number of images: 87
# Done !!!
# Processing for 133: 148
# Number of images: 87
# Done !!!
# Processing for 134: 149
# Number of images: 87
# Done !!!
# Processing for 135: 150
# Number of images: 87
# Done !!!
# Processing for 136: 151
# Number of images: 87
# Done !!!
# Processing for 137: 152
# Number of images: 87
# Done !!!
# Processing for 138: 153
# Number of images: 87
# Done !!!
# Processing for 139: 154
# Number of images: 87
# Done !!!
# Processing for 140: 155
# Number of images: 87
# Done !!!
# Processing for 141: 156
# Number of images: 87
# Done !!!
# Processing for 142: 157
# Number of images: 86
# Done !!!
# Processing for 143: 158
# Number of images: 86
# Done !!!
# Processing for 144: 159
# Number of images: 86
# Done !!!
# Processing for 145: 160
# Number of images: 86
# Done !!!
# Processing for 146: 161
# Number of images: 86
# Done !!!
# Processing for 147: 162
# Number of images: 87
# Done !!!
# Processing for 148: 163
# Number of images: 86
# Done !!!
# Processing for 149: 164
# Number of images: 87
# Done !!!
# Processing for 150: 165
# Number of images: 87
# Done !!!
# Processing for 151: 166
# Number of images: 87
# Done !!!
# Processing for 152: 167
# Number of images: 87
# Done !!!
# Processing for 153: 168
# Number of images: 87
# Done !!!
# Processing for 154: 169
# Number of images: 87
# Done !!!
# Processing for 155: 170
# Number of images: 87
# Done !!!
# Processing for 156: 171
# Number of images: 87
# Done !!!
# Processing for 157: 172
# Number of images: 87
# Done !!!
# Processing for 158: 173
# Number of images: 87
# Done !!!
# Processing for 159: 174
# Number of images: 87
# Done !!!
# Processing for 160: 175
# Number of images: 87
# Done !!!
# Processing for 161: 176
# Number of images: 87
# Done !!!
# Processing for 162: 177
# Number of images: 87
# Done !!!
# Processing for 163: 178
# Number of images: 87
# Done !!!
# Processing for 164: 179
# Number of images: 87
# Done !!!
# Processing for 165: 180
# Number of images: 87
# Done !!!
# Processing for 166: 181
# Number of images: 87
# Done !!!
# Processing for 167: 182
# Number of images: 87
# Done !!!
# Processing for 168: 183
# Number of images: 92
# Done !!!
# Processing for 169: 184
# Number of images: 86
# Done !!!
# Processing for 170: 185
# Number of images: 86
# Done !!!
# Processing for 171: 186
# Number of images: 87
# Done !!!
# Processing for 172: 187
# Number of images: 87
# Done !!!
# Processing for 173: 188
# Number of images: 87
# Done !!!
# Processing for 174: 189
# Number of images: 87
# Done !!!
# Processing for 175: 190
# Number of images: 87
# Done !!!
# Processing for 176: 191
# Number of images: 87
# Done !!!
# Processing for 177: 192
# Number of images: 87
# Done !!!
# Processing for 178: 193
# Number of images: 87
# Done !!!
# Processing for 179: 194
# Number of images: 87
# Done !!!
# Processing for 180: 195
# Number of images: 87
# Done !!!
# Processing for 181: 196
# Number of images: 87
# Done !!!
# Processing for 182: 197
# Number of images: 87
# Done !!!
# Processing for 183: 198
# Number of images: 87
# Done !!!
# Processing for 184: 200
# Number of images: 87
# Done !!!
# Processing for 185: 201
# Number of images: 87
# Done !!!
# Processing for 186: 202
# Number of images: 87
# Done !!!
# Processing for 187: 203
# Number of images: 87
# Done !!!
# Processing for 188: 204
# Number of images: 87
# Done !!!
# Processing for 189: 205
# Number of images: 87
# Done !!!
# Processing for 190: 206
# Number of images: 87
# Done !!!
# Processing for 191: 208
# Number of images: 87
# Done !!!
# Processing for 192: 209
# Number of images: 122
# Done !!!
# Processing for 193: 210
# Number of images: 87
# Done !!!
# Processing for 194: 211
# Number of images: 87
# Done !!!
# Processing for 195: 212
# Number of images: 87
# Done !!!
# Processing for 196: 213
# Number of images: 87
# Done !!!
# Processing for 197: 214
# Number of images: 87
# Done !!!
# Processing for 198: 215
# Number of images: 87
# Done !!!
# Processing for 199: 216
# Number of images: 87
# Done !!!
# Processing for 200: 217
# Number of images: 87
# Done !!!
# Processing for 201: 218
# Number of images: 87
# Done !!!
# Processing for 202: 219
# Number of images: 87
# Done !!!
# Processing for 203: 220
# Number of images: 87
# Done !!!
# Processing for 204: 221
# Number of images: 87
# Done !!!
# Processing for 205: 222
# Number of images: 87
# Done !!!
# Processing for 206: 223
# Number of images: 87
# Done !!!
# Processing for 207: 226
# Number of images: 87
# Done !!!
# Processing for 208: 227
# Number of images: 87
# Done !!!
# Processing for 209: 228
# Number of images: 87
# Done !!!
# Processing for 210: 229
# Number of images: 87
# Done !!!
# Processing for 211: 230
# Number of images: 87
# Done !!!
# Processing for 212: 231
# Number of images: 87
# Done !!!
# Processing for 213: 232
# Number of images: 87
# Done !!!
# Processing for 214: 233
# Number of images: 87
# Done !!!
# Processing for 215: 234
# Number of images: 87
# Done !!!
# Processing for 216: 235
# Number of images: 91
# Done !!!
# Processing for 217: 236
# Number of images: 87
# Done !!!
# Processing for 218: 237
# Number of images: 87
# Done !!!
# Processing for 219: 238
# Number of images: 87
# Done !!!
# Processing for 220: 239
# Number of images: 87
# Done !!!
# Processing for 221: 240
# Number of images: 87
# Done !!!
# Processing for 222: 241
# Number of images: 87
# Done !!!
# Processing for 223: 242
# Number of images: 87
# Done !!!
# Processing for 224: 243
# Number of images: 87
# Done !!!
# Processing for 225: 244
# Number of images: 87
# Done !!!
# Processing for 226: 245
# Number of images: 87
# Done !!!
# Processing for 227: 246
# Number of images: 87
# Done !!!
# Processing for 228: 247
# Number of images: 87
# Done !!!
# Processing for 229: 248
# Number of images: 87
# Done !!!
# Processing for 230: 249
# Number of images: 87
# Done !!!
# Processing for 231: 254
# Number of images: 87
# Done !!!
# Processing for 232: 255
# Number of images: 87
# Done !!!
# Processing for 233: 256
# Number of images: 87
# Done !!!
# Processing for 234: 257
# Number of images: 87
# Done !!!
# Processing for 235: 258
# Number of images: 87
# Done !!!
# Processing for 236: 259
# Number of images: 87
# Done !!!
# Processing for 237: 260
# Number of images: 87
# Done !!!
# Processing for 238: 261
# Number of images: 175
# Done !!!
# Processing for 239: 262
# Number of images: 87
# Done !!!
# Processing for 240: 263
# Number of images: 87
# Done !!!
# Processing for 241: 264
# Number of images: 87
# Done !!!
# Processing for 242: 265
# Number of images: 87
# Done !!!
# Processing for 243: 266
# Number of images: 87
# Done !!!
# Processing for 244: 267
# Number of images: 87
# Done !!!
# Processing for 245: 268
# Number of images: 87
# Done !!!
# Processing for 246: 269
# Number of images: 87
# Done !!!
# Processing for 247: 270
# Number of images: 87
# Done !!!
# Processing for 248: 271
# Number of images: 87
# Done !!!
# Processing for 249: 272
# Number of images: 87
# Done !!!
# Processing for 250: 273
# Number of images: 87
# Done !!!
# Processing for 251: 274
# Number of images: 87
# Done !!!
# Processing for 252: 275
# Number of images: 87
# Done !!!
# Processing for 253: 276
# Number of images: 87
# Done !!!
# Processing for 254: 279
# Number of images: 87
# Done !!!
# Processing for 255: 280
# Number of images: 87
# Done !!!
# Processing for 256: 281
# Number of images: 87
# Done !!!
# Processing for 257: 282
# Number of images: 87
# Done !!!
# Processing for 258: 283
# Number of images: 87
# Done !!!
# Processing for 259: 284
# Number of images: 87
# Done !!!
# Processing for 260: 285
# Number of images: 87
# Done !!!
# Processing for 261: 286
# Number of images: 87
# Done !!!
# Processing for 262: 287
# Number of images: 175
# Done !!!
# Processing for 263: 288
# Number of images: 87
# Done !!!
# Processing for 264: 289
# Number of images: 87
# Done !!!
# Processing for 265: 290
# Number of images: 87
# Done !!!
# Processing for 266: 291
# Number of images: 87
# Done !!!
# Processing for 267: 292
# Number of images: 87
# Done !!!
# Processing for 268: 293
# Number of images: 87
# Done !!!
# Processing for 269: 294
# Number of images: 87
# Done !!!
# Processing for 270: 295
# Number of images: 87
# Done !!!
# Processing for 271: 296
# Number of images: 87
# Done !!!
# Processing for 272: 297
# Number of images: 87
# Done !!!
# Processing for 273: 298
# Number of images: 87
# Done !!!
# Processing for 274: 299
# Number of images: 87
# Done !!!
# Processing for 275: 300
# Number of images: 87
# Done !!!
# Processing for 276: 301
# Number of images: 87
# Done !!!
# Processing for 277: 303
# Number of images: 87
# Done !!!
# Processing for 278: 304
# Number of images: 87
# Done !!!
# Processing for 279: 305
# Number of images: 87
# Done !!!
# Processing for 280: 307
# Number of images: 87
# Done !!!
# Processing for 281: 308
# Number of images: 87
# Done !!!
# Processing for 282: 309
# Number of images: 87
# Done !!!
# Processing for 283: 310
# Number of images: 87
# Done !!!
# Processing for 284: 311
# Number of images: 87
# Done !!!
# Processing for 285: 312
# Number of images: 87
# Done !!!
# Processing for 286: 313
# Number of images: 173
# Done !!!
# Processing for 287: 314
# Number of images: 95
# Done !!!
# Processing for 288: 315
# Number of images: 87
# Done !!!
# Processing for 289: 316
# Number of images: 87
# Done !!!
# Processing for 290: 317
# Number of images: 87
# Done !!!
# Processing for 291: 318
# Number of images: 87
# Done !!!
# Processing for 292: 319
# Number of images: 87
# Done !!!
# Processing for 293: 320
# Number of images: 87
# Done !!!
# Processing for 294: 321
# Number of images: 87
# Done !!!
# Processing for 295: 322
# Number of images: 87
# Done !!!
# Processing for 296: 324
# Number of images: 87
# Done !!!
# Processing for 297: 325
# Number of images: 87
# Done !!!
# Processing for 298: 326
# Number of images: 87
# Done !!!
# Processing for 299: 327
# Number of images: 87
# Done !!!
# Processing for 300: 328
# Number of images: 87
# Done !!!
# Processing for 301: 329
# Number of images: 87
# Done !!!
# Processing for 302: 330
# Number of images: 87
# Done !!!
# Processing for 303: 331
# Number of images: 87
# Done !!!
# Processing for 304: 332
# Number of images: 87
# Done !!!
# Processing for 305: 333
# Number of images: 87
# Done !!!
# Processing for 306: 334
# Number of images: 87
# Done !!!
# Processing for 307: 335
# Number of images: 87
# Done !!!
# Processing for 308: 336
# Number of images: 87
# Done !!!
# Processing for 309: 337
# Number of images: 87
# Done !!!
# Processing for 310: 338
# Number of images: 87
# Done !!!
# Processing for 311: 339
# Number of images: 175
# Done !!!
# Processing for 312: 340
# Number of images: 175
# Done !!!
# Processing for 313: 341
# Number of images: 87
# Done !!!
# Processing for 314: 342
# Number of images: 87
# Done !!!
# Processing for 315: 343
# Number of images: 87
# Done !!!
# Processing for 316: 344
# Number of images: 87
# Done !!!
# Processing for 317: 345
# Number of images: 87
# Done !!!
# Processing for 318: 346
# Number of images: 87
# Done !!!
# Processing for 319: 347
# Number of images: 87
# Done !!!
# Processing for 320: 348
# Number of images: 87
# Done !!!
# Processing for 321: 351
# Number of images: 87
# Done !!!
# Processing for 322: 352
# Number of images: 87
# Done !!!
# Processing for 323: 353
# Number of images: 87
# Done !!!
# Processing for 324: 354
# Number of images: 87
# Done !!!
# Processing for 325: 358
# Number of images: 87
# Done !!!
# Processing for 326: 359
# Number of images: 87
# Done !!!
# Processing for 327: 360
# Number of images: 87
# Done !!!
# Processing for 328: 361
# Number of images: 87
# Done !!!
# Processing for 329: 362
# Number of images: 87
# Done !!!
# Processing for 330: 363
# Number of images: 87
# Done !!!
# Processing for 331: 364
# Number of images: 87
# Done !!!
# Processing for 332: 365
# Number of images: 175
# Done !!!
# Processing for 333: 366
# Number of images: 93
# Done !!!
# Processing for 334: 367
# Number of images: 87
# Done !!!
# Processing for 335: 368
# Number of images: 87
# Done !!!
# Processing for 336: 369
# Number of images: 87
# Done !!!
# Processing for 337: 370
# Number of images: 87
# Done !!!
# Processing for 338: 371
# Number of images: 87
# Done !!!
# Processing for 339: 372
# Number of images: 87
# Done !!!
# Processing for 340: 373
# Number of images: 87
# Done !!!
# Processing for 341: 374
# Number of images: 87
# Done !!!
# Processing for 342: 375
# Number of images: 87
# Done !!!
# Processing for 343: 376
# Number of images: 87
# Done !!!
# Processing for 344: 377
# Number of images: 87
# Done !!!
# Processing for 345: 379
# Number of images: 87
# Done !!!
# Processing for 346: 380
# Number of images: 87
# Done !!!
# Processing for 347: 383
# Number of images: 87
# Done !!!
# Processing for 348: 384
# Number of images: 87
# Done !!!
# Processing for 349: 385
# Number of images: 87
# Done !!!
# Processing for 350: 386
# Number of images: 87
# Done !!!
# Processing for 351: 387
# Number of images: 87
# Done !!!
# Processing for 352: 388
# Number of images: 87
# Done !!!
# Processing for 353: 389
# Number of images: 87
# Done !!!
# Processing for 354: 390
# Number of images: 87
# Done !!!
# Processing for 355: 391
# Number of images: 175
# Done !!!
# Processing for 356: 392
# Number of images: 175
# Done !!!
# Processing for 357: 393
# Number of images: 87
# Done !!!
# Processing for 358: 394
# Number of images: 87
# Done !!!
# Processing for 359: 395
# Number of images: 87
# Done !!!
# Processing for 360: 396
# Number of images: 87
# Done !!!
# Processing for 361: 397
# Number of images: 87
# Done !!!
# Processing for 362: 398
# Number of images: 87
# Done !!!
# Processing for 363: 399
# Number of images: 87
# Done !!!
# Processing for 364: 400
# Number of images: 87
# Done !!!
# Processing for 365: 401
# Number of images: 87
# Done !!!
# Processing for 366: 402
# Number of images: 87
# Done !!!
# Processing for 367: 403
# Number of images: 87
# Done !!!
# Processing for 368: 404
# Number of images: 87
# Done !!!
# Processing for 369: 405
# Number of images: 87
# Done !!!
# Processing for 370: 406
# Number of images: 87
# Done !!!
# Processing for 371: 408
# Number of images: 87
# Done !!!
# Processing for 372: 409
# Number of images: 87
# Done !!!
# Processing for 373: 410
# Number of images: 87
# Done !!!
# Processing for 374: 411
# Number of images: 87
# Done !!!
# Processing for 375: 412
# Number of images: 87
# Done !!!
# Processing for 376: 413
# Number of images: 87
# Done !!!
# Processing for 377: 414
# Number of images: 87
# Done !!!
# Processing for 378: 415
# Number of images: 87
# Done !!!
# Processing for 379: 416
# Number of images: 87
# Done !!!
# Processing for 380: 417
# Number of images: 175
# Done !!!
# Processing for 381: 418
# Number of images: 175
# Done !!!
# Processing for 382: 419
# Number of images: 175
# Done !!!
# Processing for 383: 420
# Number of images: 87
# Done !!!
# Processing for 384: 421
# Number of images: 87
# Done !!!
# Processing for 385: 422
# Number of images: 87
# Done !!!
# Processing for 386: 423
# Number of images: 87
# Done !!!
# Processing for 387: 424
# Number of images: 87
# Done !!!
# Processing for 388: 425
# Number of images: 87
# Done !!!
# Processing for 389: 426
# Number of images: 87
# Done !!!
# Processing for 390: 427
# Number of images: 87
# Done !!!
# Processing for 391: 428
# Number of images: 87
# Done !!!
# Processing for 392: 429
# Number of images: 87
# Done !!!
# Processing for 393: 432
# Number of images: 87
# Done !!!
# Processing for 394: 434
# Number of images: 87
# Done !!!
# Processing for 395: 435
# Number of images: 87
# Done !!!
# Processing for 396: 436
# Number of images: 87
# Done !!!
# Processing for 397: 437
# Number of images: 87
# Done !!!
# Processing for 398: 438
# Number of images: 87
# Done !!!
# Processing for 399: 439
# Number of images: 87
# Done !!!
# Processing for 400: 440
# Number of images: 87
# Done !!!
# Processing for 401: 441
# Number of images: 87
# Done !!!
# Processing for 402: 442
# Number of images: 87
# Done !!!
# Processing for 403: 443
# Number of images: 175
# Done !!!
# Processing for 404: 444
# Number of images: 175
# Done !!!
# Processing for 405: 445
# Number of images: 138
# Done !!!
# Processing for 406: 446
# Number of images: 87
# Done !!!
# Processing for 407: 447
# Number of images: 87
# Done !!!
# Processing for 408: 448
# Number of images: 87
# Done !!!
# Processing for 409: 449
# Number of images: 87
# Done !!!
# Processing for 410: 450
# Number of images: 87
# Done !!!
# Processing for 411: 451
# Number of images: 87
# Done !!!
# Processing for 412: 452
# Number of images: 87
# Done !!!
# Processing for 413: 453
# Number of images: 87
# Done !!!
# Processing for 414: 455
# Number of images: 87
# Done !!!
# Processing for 415: 458
# Number of images: 87
# Done !!!
# Processing for 416: 459
# Number of images: 87
# Done !!!
# Processing for 417: 460
# Number of images: 87
# Done !!!
# Processing for 418: 461
# Number of images: 87
# Done !!!
# Processing for 419: 462
# Number of images: 87
# Done !!!
# Processing for 420: 463
# Number of images: 87
# Done !!!
# Processing for 421: 464
# Number of images: 87
# Done !!!
# Processing for 422: 466
# Number of images: 87
# Done !!!
# Processing for 423: 467
# Number of images: 87
# Done !!!
# Processing for 424: 468
# Number of images: 87
# Done !!!
# Processing for 425: 469
# Number of images: 175
# Done !!!
# Processing for 426: 470
# Number of images: 175
# Done !!!
# Processing for 427: 471
# Number of images: 90
# Done !!!
# Processing for 428: 472
# Number of images: 87
# Done !!!
# Processing for 429: 473
# Number of images: 87
# Done !!!
# Processing for 430: 474
# Number of images: 87
# Done !!!
# Processing for 431: 475
# Number of images: 87
# Done !!!
# Processing for 432: 476
# Number of images: 87
# Done !!!
# Processing for 433: 477
# Number of images: 87
# Done !!!
# Processing for 434: 478
# Number of images: 87
# Done !!!
# Processing for 435: 479
# Number of images: 87
# Done !!!
# Processing for 436: 480
# Number of images: 87
# Done !!!
# Processing for 437: 483
# Number of images: 87
# Done !!!
# Processing for 438: 484
# Number of images: 87
# Done !!!
# Processing for 439: 485
# Number of images: 87
# Done !!!
# Processing for 440: 486
# Number of images: 87
# Done !!!
# Processing for 441: 487
# Number of images: 87
# Done !!!
# Processing for 442: 488
# Number of images: 87
# Done !!!
# Processing for 443: 489
# Number of images: 87
# Done !!!
# Processing for 444: 490
# Number of images: 87
# Done !!!
# Processing for 445: 491
# Number of images: 87
# Done !!!
# Processing for 446: 493
# Number of images: 87
# Done !!!
# Processing for 447: 494
# Number of images: 87
# Done !!!
# Processing for 448: 495
# Number of images: 175
# Done !!!
# Processing for 449: 496
# Number of images: 175
# Done !!!
# Processing for 450: 497
# Number of images: 135
# Done !!!
# Processing for 451: 498
# Number of images: 87
# Done !!!
# Processing for 452: 499
# Number of images: 87
# Done !!!
# Processing for 453: 500
# Number of images: 87
# Done !!!
# Processing for 454: 501
# Number of images: 87
# Done !!!
# Processing for 455: 502
# Number of images: 87
# Done !!!
# Processing for 456: 503
# Number of images: 87
# Done !!!
# Processing for 457: 504
# Number of images: 87
# Done !!!
# Processing for 458: 505
# Number of images: 87
# Done !!!
# Processing for 459: 506
# Number of images: 87
# Done !!!
# Processing for 460: 507
# Number of images: 87
# Done !!!
# Processing for 461: 508
# Number of images: 87
# Done !!!
# Processing for 462: 509
# Number of images: 87
# Done !!!
# Processing for 463: 510
# Number of images: 87
# Done !!!
# Processing for 464: 511
# Number of images: 87
# Done !!!
# Processing for 465: 512
# Number of images: 87
# Done !!!
# Processing for 466: 513
# Number of images: 87
# Done !!!
# Processing for 467: 514
# Number of images: 87
# Done !!!
# Processing for 468: 516
# Number of images: 87
# Done !!!
# Processing for 469: 517
# Number of images: 87
# Done !!!
# Processing for 470: 518
# Number of images: 87
# Done !!!
# Processing for 471: 519
# Number of images: 87
# Done !!!
# Processing for 472: 520
# Number of images: 87
# Done !!!
# Processing for 473: 521
# Number of images: 175
# Done !!!
# Processing for 474: 522
# Number of images: 175
# Done !!!
# Processing for 475: 523
# Number of images: 175
# Done !!!
# Processing for 476: 524
# Number of images: 93
# Done !!!
# Processing for 477: 525
# Number of images: 87
# Done !!!
# Processing for 478: 526
# Number of images: 87
# Done !!!
# Processing for 479: 527
# Number of images: 87
# Done !!!
# Processing for 480: 528
# Number of images: 87
# Done !!!
# Processing for 481: 529
# Number of images: 87
# Done !!!
# Processing for 482: 530
# Number of images: 87
# Done !!!
# Processing for 483: 531
# Number of images: 87
# Done !!!
# Processing for 484: 533
# Number of images: 87
# Done !!!
# Processing for 485: 534
# Number of images: 87
# Done !!!
# Processing for 486: 535
# Number of images: 87
# Done !!!
# Processing for 487: 536
# Number of images: 87
# Done !!!
# Processing for 488: 537
# Number of images: 87
# Done !!!
# Processing for 489: 538
# Number of images: 87
# Done !!!
# Processing for 490: 539
# Number of images: 87
# Done !!!
# Processing for 491: 540
# Number of images: 87
# Done !!!
# Processing for 492: 541
# Number of images: 87
# Done !!!
# Processing for 493: 542
# Number of images: 87
# Done !!!
# Processing for 494: 543
# Number of images: 87
# Done !!!
# Processing for 495: 544
# Number of images: 87
# Done !!!
# Processing for 496: 545
# Number of images: 87
# Done !!!
# Processing for 497: 546
# Number of images: 87
# Done !!!
# Processing for 498: 547
# Number of images: 175
# Done !!!
# Processing for 499: 549
# Number of images: 175
# Done !!!
# Processing for 500: 550
# Number of images: 87
# Done !!!
# Processing for 501: 551
# Number of images: 87
# Done !!!
# Processing for 502: 552
# Number of images: 87
# Done !!!
# Processing for 503: 553
# Number of images: 87
# Done !!!
# Processing for 504: 554
# Number of images: 87
# Done !!!
# Processing for 505: 555
# Number of images: 87
# Done !!!
# Processing for 506: 556
# Number of images: 87
# Done !!!
# Processing for 507: 557
# Number of images: 87
# Done !!!
# Processing for 508: 558
# Number of images: 87
# Done !!!
# Processing for 509: 559
# Number of images: 87
# Done !!!
# Processing for 510: 560
# Number of images: 87
# Done !!!
# Processing for 511: 561
# Number of images: 87
# Done !!!
# Processing for 512: 562
# Number of images: 87
# Done !!!
# Processing for 513: 563
# Number of images: 87
# Done !!!
# Processing for 514: 564
# Number of images: 87
# Done !!!
# Processing for 515: 565
# Number of images: 87
# Done !!!
# Processing for 516: 566
# Number of images: 87
# Done !!!
# Processing for 517: 567
# Number of images: 87
# Done !!!
# Processing for 518: 568
# Number of images: 87
# Done !!!
# Processing for 519: 569
# Number of images: 87
# Done !!!
# Processing for 520: 570
# Number of images: 87
# Done !!!
# Processing for 521: 572
# Number of images: 87
# Done !!!
# Processing for 522: 573
# Number of images: 175
# Done !!!
# Processing for 523: 574
# Number of images: 175
# Done !!!
# Processing for 524: 575
# Number of images: 175
# Done !!!
# Processing for 525: 576
# Number of images: 175
# Done !!!
# Processing for 526: 577
# Number of images: 91
# Done !!!
# Processing for 527: 578
# Number of images: 87
# Done !!!
# Processing for 528: 579
# Number of images: 87
# Done !!!
# Processing for 529: 580
# Number of images: 87
# Done !!!
# Processing for 530: 581
# Number of images: 87
# Done !!!
# Processing for 531: 582
# Number of images: 87
# Done !!!
# Processing for 532: 583
# Number of images: 87
# Done !!!
# Processing for 533: 584
# Number of images: 87
# Done !!!
# Processing for 534: 585
# Number of images: 87
# Done !!!
# Processing for 535: 586
# Number of images: 87
# Done !!!
# Processing for 536: 587
# Number of images: 87
# Done !!!
# Processing for 537: 588
# Number of images: 87
# Done !!!
# Processing for 538: 589
# Number of images: 87
# Done !!!
# Processing for 539: 590
# Number of images: 87
# Done !!!
# Processing for 540: 591
# Number of images: 87
# Done !!!
# Processing for 541: 592
# Number of images: 87
# Done !!!
# Processing for 542: 593
# Number of images: 87
# Done !!!
# Processing for 543: 594
# Number of images: 87
# Done !!!
# Processing for 544: 595
# Number of images: 87
# Done !!!
# Processing for 545: 596
# Number of images: 87
# Done !!!
# Processing for 546: 597
# Number of images: 87
# Done !!!
# Processing for 547: 598
# Number of images: 87
# Done !!!
# Processing for 548: 599
# Number of images: 175
# Done !!!
# Processing for 549: 600
# Number of images: 175
# Done !!!
# Processing for 550: 601
# Number of images: 175
# Done !!!
# Processing for 551: 602
# Number of images: 120
# Done !!!
# Processing for 552: 603
# Number of images: 87
# Done !!!
# Processing for 553: 604
# Number of images: 87
# Done !!!
# Processing for 554: 605
# Number of images: 87
# Done !!!
# Processing for 555: 606
# Number of images: 87
# Done !!!
# Processing for 556: 607
# Number of images: 87
# Done !!!
# Processing for 557: 608
# Number of images: 87
# Done !!!
# Processing for 558: 609
# Number of images: 87
# Done !!!
# Processing for 559: 610
# Number of images: 87
# Done !!!
# Processing for 560: 611
# Number of images: 87
# Done !!!
# Processing for 561: 612
# Number of images: 87
# Done !!!
# Processing for 562: 614
# Number of images: 87
# Done !!!
# Processing for 563: 615
# Number of images: 87
# Done !!!
# Processing for 564: 616
# Number of images: 87
# Done !!!
# Processing for 565: 617
# Number of images: 87
# Done !!!
# Processing for 566: 618
# Number of images: 87
# Done !!!
# Processing for 567: 619
# Number of images: 87
# Done !!!
# Processing for 568: 620
# Number of images: 87
# Done !!!
# Processing for 569: 621
# Number of images: 87
# Done !!!
# Processing for 570: 622
# Number of images: 87
# Done !!!
# Processing for 571: 623
# Number of images: 87
# Done !!!
# Processing for 572: 624
# Number of images: 87
# Done !!!
# Processing for 573: 625
# Number of images: 175
# Done !!!
# Processing for 574: 626
# Number of images: 175
# Done !!!
# Processing for 575: 627
# Number of images: 175
# Done !!!
# Processing for 576: 628
# Number of images: 162
# Done !!!
# Processing for 577: 629
# Number of images: 87
# Done !!!
# Processing for 578: 630
# Number of images: 87
# Done !!!
# Processing for 579: 631
# Number of images: 87
# Done !!!
# Processing for 580: 632
# Number of images: 87
# Done !!!
# Processing for 581: 633
# Number of images: 87
# Done !!!
# Processing for 582: 634
# Number of images: 87
# Done !!!
# Processing for 583: 635
# Number of images: 87
# Done !!!
# Processing for 584: 636
# Number of images: 87
# Done !!!
# Processing for 585: 637
# Number of images: 87
# Done !!!
# Processing for 586: 639
# Number of images: 87
# Done !!!
# Processing for 587: 640
# Number of images: 87
# Done !!!
# Processing for 588: 642
# Number of images: 87
# Done !!!
# Processing for 589: 643
# Number of images: 87
# Done !!!
# Processing for 590: 644
# Number of images: 87
# Done !!!
# Processing for 591: 645
# Number of images: 87
# Done !!!
# Processing for 592: 646
# Number of images: 87
# Done !!!
# Processing for 593: 647
# Number of images: 87
# Done !!!
# Processing for 594: 648
# Number of images: 87
# Done !!!
# Processing for 595: 649
# Number of images: 87
# Done !!!
# Processing for 596: 650
# Number of images: 87
# Done !!!

# %% [markdown]
# ### Extract input data for inference

# %%
# Select rectangle 2 because SMs ossilates in this area
csv_path = '/mnt/data2tb/Transfer-DenseSM-E/India/visualize/visualization_swc_values_2.csv'
sites = pd.read_csv(csv_path, float_precision="high")

batch_size = 50
delay = 30 

# Split sites into batches
batches = [sites[i:i + batch_size] for i in range(0, len(sites), batch_size)]
if len(sites) % batch_size != 0:
    batches.append(sites[len(sites) - len(sites) % batch_size:])

all_samples = []

for batch_id, batch in enumerate(batches[:30]):
    print(f"Processing batch {batch_id + 1}/{len(batches)} with {len(batch)} sites")
    for i, row in batch.iterrows():
        print(f"Processing for {i}: {row['location']}")
        ring_wgs, grid_ring = pobj.get_wgs_grid(row['lon'], row['lat'])
        polygon_grid = ee.Geometry.Polygon(ring_wgs, 'EPSG:4326', True, 20, False)
        samples, df_S1 = utils_data_pre.samples_4_grid_v1(polygon_grid, START_DATE, END_DATE, START_DATE_NDVI, END_DATE_NDVI, ring_wgs, pobj, grid_size)

        df_S1['date'] = pd.to_datetime(df_S1['date']).dt.strftime('%Y-%m-%d')

        station_sm = row['sm_25']
        print(station_sm)
        

        single_date = pd.to_datetime(row['date']).strftime('%Y-%m-%d')

        df_S1 = df_S1[df_S1['date'] == single_date]
        
        samples = pd.DataFrame(samples)
        samples = samples.loc[df_S1.index]

        df_S1 = df_S1.copy()
        df_S1['sm_25'] = row['sm_25']

        result = pd.concat([df_S1.reset_index(drop=True), samples.reset_index(drop=True)], axis = 1)
        result.insert(0, 'location', row['location'])


        result.dropna(inplace=True)
        result.to_csv('result.csv', index = False)
        all_samples.append(result)

    if batch_id < len(batches) - 1:
        print(f"Sleeping for {delay} seconds...")
        time.sleep(delay)

final_df = pd.concat(all_samples, ignore_index=True)
final_df.dropna(inplace=True)
final_df.to_csv('final_result.csv', index=False)
print(final_df.head())
